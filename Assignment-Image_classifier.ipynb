# %%
import torch
import torchvision
import torchvision.transforms as transforms

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# %%
trainset = torchvision.datasets.CIFAR10(root='/Users/anoushka/Downloads/cifar10/cifar10/train', train=True, download=True, transform=transform)
testset = torchvision.datasets.CIFAR10(root='/Users/anoushka/Downloads/cifar10/cifar10/test', train=False, download=True, transform=transform)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
from torch.utils.data.dataset import random_split

train_size = int(0.8 * len(trainset))
val_size = len(trainset) - train_size
train_dataset, val_dataset = random_split(trainset, [train_size, val_size])

# %%
from torch.utils.data import DataLoader
trainloader = DataLoader(train_dataset, batch_size=4, shuffle=True, num_workers=2)
valloader = DataLoader(val_dataset, batch_size=4, shuffle=False, num_workers=2)
testloader = DataLoader(testset, batch_size=4, shuffle=False, num_workers=2)

# %%
height, width = trainset[0][0].shape[1], trainset[0][0].shape[2]

print("Image Height:", height)
print("Image Width:", width)
# Out:
# Image Height: 32
# Image Width: 32

# %%
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        # Define convolutional layers
        self.conv1 = nn.Conv2d(3, 10, 3) 
        self.conv2 = nn.Conv2d(10, 16, 3)
        # Define pooling layer
        self.pool = nn.MaxPool2d(2, 2) # 2x2 max pooling
        # Define fully connected layers
        self.fc1 = nn.Linear(16 * 6 * 6, 120) 
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10) 

    def forward(self, x):
        # Define the forward pass
        x = self.pool(F.relu(self.conv1(x))) # Convolution -> Activation -> Pooling
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 6* 6) # Flatten the tensor for the fully connected layer
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x) # No activation, this is raw output (logits)
        return x

net_without_dropout = Net()

# %%
criterion = nn.CrossEntropyLoss()

# %%
for batch in trainloader:
    inputs, labels = batch
    # Now, you can print the labels for this batch
    print("Labels:", labels)
# Out:
# Labels: tensor([3, 5, 7, 6])
# Labels: tensor([6, 6, 8, 3])
# Labels: tensor([8, 8, 8, 5])
# Labels: tensor([4, 4, 5, 1])
# Labels: tensor([4, 3, 3, 7])
# Labels: tensor([5, 7, 4, 5])
# Labels: tensor([7, 5, 5, 3])
# Labels: tensor([7, 9, 3, 0])
# Labels: tensor([7, 2, 8, 2])
# Labels: tensor([9, 5, 7, 4])
# Labels: tensor([3, 2, 8, 7])
# Labels: tensor([6, 5, 8, 6])
# Labels: tensor([5, 2, 0, 1])
# Labels: tensor([1, 0, 3, 5])
# Labels: tensor([2, 1, 4, 8])
# Labels: tensor([8, 5, 4, 9])
# Labels: tensor([2, 3, 3, 6])
# Labels: tensor([2, 3, 4, 8])
# Labels: tensor([4, 3, 3, 9])
# Labels: tensor([8, 9, 9, 8])
# Labels: tensor([5, 0, 0, 1])
# Labels: tensor([0, 1, 0, 8])
# Labels: tensor([9, 2, 8, 1])
# Labels: tensor([6, 3, 9, 8])
# Labels: tensor([6, 3, 3, 2])
# Labels: tensor([5, 4, 7, 8])
# Labels: tensor([2, 4, 7, 5])
# Labels: tensor([7, 6, 3, 7])
# Labels: tensor([9, 8, 0, 0])
# Labels: tensor([9, 9, 4, 8])
# Labels: tensor([3, 7, 2, 1])
# Labels: tensor([3, 6, 2, 5])
# Labels: tensor([4, 5, 2, 8])
# Labels: tensor([4, 1, 5, 5])
# Labels: tensor([3, 1, 0, 0])
# Labels: tensor([4, 5, 2, 6])
# Labels: tensor([4, 1, 2, 2])
# Labels: tensor([9, 1, 8, 5])
# Labels: tensor([3, 6, 3, 6])
# Labels: tensor([3, 7, 2, 1])
# Labels: tensor([3, 2, 3, 5])
# Labels: tensor([7, 6, 8, 2])
# Labels: tensor([8, 9, 1, 1])
# Labels: tensor([1, 8, 2, 8])
# Labels: tensor([2, 2, 9, 2])
# Labels: tensor([1, 5, 4, 5])
# Labels: tensor([5, 3, 7, 7])
# Labels: tensor([2, 4, 5, 2])
# Labels: tensor([6, 1, 8, 6])
# Labels: tensor([4, 8, 8, 9])
# Labels: tensor([3, 9, 9, 9])
# Labels: tensor([8, 1, 3, 0])
# Labels: tensor([1, 9, 3, 9])
# Labels: tensor([4, 1, 5, 9])
# Labels: tensor([0, 1, 7, 7])
# Labels: tensor([5, 6, 3, 7])
# Labels: tensor([8, 3, 1, 9])
# Labels: tensor([8, 3, 7, 9])
# Labels: tensor([3, 1, 9, 7])
# Labels: tensor([4, 4, 7, 8])
# Labels: tensor([1, 3, 1, 1])
# Labels: tensor([0, 3, 2, 2])
# Labels: tensor([8, 7, 1, 2])
# Labels: tensor([5, 8, 1, 9])
# Labels: tensor([7, 9, 6, 7])
# Labels: tensor([3, 6, 0, 9])
# Labels: tensor([4, 8, 6, 5])
# Labels: tensor([6, 1, 1, 2])
# Labels: tensor([5, 7, 4, 2])
# Labels: tensor([0, 4, 5, 0])
# Labels: tensor([9, 5, 8, 3])
# Labels: tensor([1, 4, 2, 7])
# Labels: tensor([4, 1, 8, 5])
# Labels: tensor([9, 4, 2, 8])
# Labels: tensor([8, 2, 9, 9])
# Labels: tensor([6, 4, 0, 5])
# Labels: tensor([5, 9, 5, 6])
# Labels: tensor([7, 4, 8, 8])
# Labels: tensor([8, 7, 4, 9])
# Labels: tensor([0, 8, 6, 8])
# Labels: tensor([1, 9, 2, 8])
# Labels: tensor([1, 6, 2, 2])
# Labels: tensor([4, 1, 1, 6])
# Labels: tensor([9, 8, 6, 3])
# Labels: tensor([2, 0, 7, 0])
# Labels: tensor([8, 1, 3, 4])
# Labels: tensor([5, 9, 8, 0])
# Labels: tensor([9, 4, 7, 2])
# Labels: tensor([6, 9, 7, 5])
# Labels: tensor([6, 6, 4, 9])
# Labels: tensor([6, 4, 6, 6])
# Labels: tensor([7, 3, 1, 5])
# Labels: tensor([7, 5, 1, 8])
# Labels: tensor([3, 6, 7, 8])
# Labels: tensor([1, 5, 5, 4])
# Labels: tensor([2, 1, 6, 8])
# Labels: tensor([0, 5, 6, 1])
# Labels: tensor([5, 2, 7, 2])
# Labels: tensor([5, 6, 1, 5])
# Labels: tensor([0, 2, 4, 7])
# Labels: tensor([5, 5, 1, 5])
# Labels: tensor([8, 2, 7, 5])
# Labels: tensor([0, 3, 9, 2])
# Labels: tensor([4, 4, 7, 5])
# Labels: tensor([7, 6, 7, 1])
# Labels: tensor([8, 3, 9, 1])
# Labels: tensor([1, 8, 3, 1])
# Labels: tensor([3, 3, 1, 7])
# Labels: tensor([6, 5, 0, 5])
# Labels: tensor([2, 3, 5, 9])
# Labels: tensor([5, 8, 1, 5])
# Labels: tensor([9, 3, 6, 6])
# Labels: tensor([7, 7, 8, 1])
# Labels: tensor([4, 9, 0, 0])
# Labels: tensor([8, 5, 8, 5])
# Labels: tensor([4, 8, 0, 4])
# Labels: tensor([3, 8, 6, 1])
# Labels: tensor([2, 5, 8, 9])
# Labels: tensor([0, 4, 5, 5])
# Labels: tensor([7, 9, 6, 5])
# Labels: tensor([7, 0, 2, 9])
# Labels: tensor([5, 7, 9, 3])
# Labels: tensor([1, 3, 0, 8])
# Labels: tensor([4, 2, 3, 1])
# Labels: tensor([9, 6, 5, 7])
# Labels: tensor([2, 7, 6, 9])
# Labels: tensor([7, 0, 6, 3])
# Labels: tensor([5, 9, 4, 8])
# Labels: tensor([0, 3, 4, 1])
# Labels: tensor([5, 9, 3, 4])
# Labels: tensor([9, 2, 4, 7])
# Labels: tensor([3, 2, 6, 8])
# Labels: tensor([3, 9, 7, 3])
# Labels: tensor([0, 1, 2, 1])
# Labels: tensor([1, 8, 5, 8])
# Labels: tensor([3, 2, 4, 6])
# Labels: tensor([5, 0, 2, 2])
# Labels: tensor([7, 0, 7, 1])
# Labels: tensor([8, 8, 2, 7])
# Labels: tensor([5, 3, 0, 2])
# Labels: tensor([8, 4, 1, 8])
# Labels: tensor([3, 5, 1, 8])
# Labels: tensor([3, 2, 8, 1])
# Labels: tensor([6, 0, 5, 5])
# Labels: tensor([9, 6, 8, 8])
# Labels: tensor([7, 0, 0, 0])
# Labels: tensor([9, 5, 3, 4])
# Labels: tensor([0, 1, 6, 8])
# Labels: tensor([5, 0, 3, 2])
# Labels: tensor([6, 2, 5, 3])
# Labels: tensor([4, 7, 6, 8])
# Labels: tensor([2, 4, 1, 3])
# Labels: tensor([3, 6, 9, 9])
# Labels: tensor([3, 9, 2, 2])
# Labels: tensor([9, 5, 7, 2])
# Labels: tensor([2, 9, 5, 1])
# Labels: tensor([0, 5, 5, 1])
# Labels: tensor([8, 8, 3, 5])
# Labels: tensor([3, 8, 1, 4])
# Labels: tensor([9, 7, 9, 6])
# Labels: tensor([4, 7, 1, 1])
# Labels: tensor([5, 1, 1, 8])
# Labels: tensor([9, 9, 0, 4])
# Labels: tensor([0, 0, 4, 9])
# Labels: tensor([2, 4, 0, 4])
# Labels: tensor([3, 7, 8, 0])
# Labels: tensor([9, 4, 6, 2])
# Labels: tensor([6, 3, 0, 9])
# Labels: tensor([9, 8, 6, 7])
# Labels: tensor([7, 0, 1, 0])
# Labels: tensor([2, 0, 9, 1])
# Labels: tensor([9, 6, 7, 1])
# Labels: tensor([9, 7, 0, 5])
# Labels: tensor([1, 1, 8, 8])
# Labels: tensor([6, 6, 4, 1])
# Labels: tensor([4, 1, 1, 3])
# Labels: tensor([3, 1, 5, 2])
# Labels: tensor([6, 9, 1, 2])
# Labels: tensor([0, 6, 7, 9])
# Labels: tensor([0, 3, 4, 4])
# Labels: tensor([5, 1, 5, 8])
# Labels: tensor([9, 2, 4, 1])
# Labels: tensor([0, 5, 8, 6])
# Labels: tensor([1, 0, 6, 1])
# Labels: tensor([6, 2, 7, 2])
# Labels: tensor([3, 6, 1, 0])
# Labels: tensor([8, 0, 4, 6])
# Labels: tensor([8, 0, 0, 9])
# Labels: tensor([6, 9, 2, 7])
# Labels: tensor([4, 2, 5, 0])
# Labels: tensor([8, 3, 0, 4])
# Labels: tensor([0, 8, 1, 8])
# Labels: tensor([9, 5, 9, 0])
# Labels: tensor([6, 5, 5, 7])
# Labels: tensor([6, 7, 1, 4])
# Labels: tensor([5, 2, 1, 2])
# Labels: tensor([7, 9, 6, 6])
# Labels: tensor([2, 8, 8, 1])
# Labels: tensor([3, 0, 7, 5])
# Labels: tensor([1, 4, 0, 5])
# Labels: tensor([6, 5, 3, 3])
# Labels: tensor([3, 8, 9, 8])
# Labels: tensor([7, 2, 9, 0])
# Labels: tensor([5, 8, 0, 3])
# Labels: tensor([9, 6, 4, 7])
# Labels: tensor([6, 6, 4, 0])
# Labels: tensor([5, 1, 0, 3])
# Labels: tensor([7, 4, 7, 3])
# Labels: tensor([2, 5, 1, 0])
# Labels: tensor([3, 4, 4, 7])
# Labels: tensor([2, 6, 4, 1])
# Labels: tensor([9, 0, 6, 7])
# Labels: tensor([0, 7, 3, 3])
# Labels: tensor([6, 9, 3, 1])
# Labels: tensor([1, 4, 8, 6])
# Labels: tensor([9, 7, 2, 0])
# Labels: tensor([1, 7, 2, 6])
# Labels: tensor([6, 6, 0, 6])
# Labels: tensor([8, 9, 3, 2])
# Labels: tensor([2, 5, 8, 7])
# Labels: tensor([2, 8, 2, 4])
# Labels: tensor([6, 1, 3, 1])
# Labels: tensor([2, 5, 2, 4])
# Labels: tensor([2, 9, 4, 4])
# Labels: tensor([6, 6, 2, 0])
# Labels: tensor([8, 3, 5, 2])
# Labels: tensor([9, 0, 7, 8])
# Labels: tensor([3, 5, 9, 1])
# Labels: tensor([4, 3, 1, 3])
# Labels: tensor([3, 6, 2, 4])
# Labels: tensor([5, 1, 8, 9])
# Labels: tensor([9, 7, 0, 0])
# Labels: tensor([6, 1, 1, 3])
# Labels: tensor([5, 8, 5, 3])
# Labels: tensor([5, 7, 4, 7])
# Labels: tensor([7, 0, 4, 2])
# Labels: tensor([0, 4, 5, 2])
# Labels: tensor([9, 5, 5, 5])
# Labels: tensor([0, 2, 1, 4])
# Labels: tensor([4, 4, 0, 4])
# Labels: tensor([4, 1, 1, 7])
# Labels: tensor([4, 6, 0, 7])
# Labels: tensor([5, 7, 9, 9])
# Labels: tensor([3, 6, 3, 4])
# Labels: tensor([5, 1, 6, 6])
# Labels: tensor([0, 6, 1, 2])
# Labels: tensor([8, 4, 4, 9])
# Labels: tensor([9, 5, 1, 6])
# Labels: tensor([4, 0, 1, 1])
# Labels: tensor([3, 1, 2, 6])
# Labels: tensor([2, 1, 5, 4])
# Labels: tensor([1, 7, 0, 0])
# Labels: tensor([0, 5, 7, 3])
# Labels: tensor([8, 5, 7, 6])
# Labels: tensor([7, 4, 4, 7])
# Labels: tensor([8, 7, 4, 9])
# Labels: tensor([5, 3, 5, 1])
# Labels: tensor([9, 2, 9, 3])
# Labels: tensor([9, 1, 6, 4])
# Labels: tensor([1, 1, 0, 2])
# Labels: tensor([6, 1, 6, 7])
# Labels: tensor([4, 0, 3, 6])
# Labels: tensor([4, 3, 4, 4])
# Labels: tensor([6, 5, 8, 9])
# Labels: tensor([6, 1, 8, 9])
# Labels: tensor([7, 3, 1, 4])
# Labels: tensor([7, 1, 8, 3])
# Labels: tensor([6, 4, 0, 2])
# Labels: tensor([3, 4, 1, 9])
# Labels: tensor([4, 8, 8, 9])
# Labels: tensor([9, 8, 1, 5])
# Labels: tensor([7, 9, 5, 4])
# Labels: tensor([6, 3, 7, 4])
# Labels: tensor([3, 7, 1, 1])
# Labels: tensor([8, 8, 8, 4])
# Labels: tensor([7, 1, 1, 0])
# Labels: tensor([6, 7, 6, 8])
# Labels: tensor([2, 0, 0, 5])
# Labels: tensor([4, 3, 7, 2])
# Labels: tensor([3, 3, 2, 5])
# Labels: tensor([0, 6, 7, 5])
# Labels: tensor([7, 6, 0, 7])
# Labels: tensor([4, 3, 5, 4])
# Labels: tensor([2, 3, 8, 9])
# Labels: tensor([3, 2, 0, 3])
# Labels: tensor([4, 1, 4, 6])
# Labels: tensor([0, 8, 8, 9])
# Labels: tensor([5, 8, 2, 1])
# Labels: tensor([3, 3, 1, 2])
# Labels: tensor([8, 3, 5, 7])
# Labels: tensor([5, 9, 1, 7])
# Labels: tensor([8, 5, 0, 8])
# Labels: tensor([6, 7, 5, 4])
# Labels: tensor([2, 3, 4, 2])
# Labels: tensor([6, 9, 3, 7])
# Labels: tensor([5, 4, 5, 7])
# Labels: tensor([1, 7, 8, 4])
# Labels: tensor([6, 7, 7, 6])
# Labels: tensor([3, 5, 5, 2])
# Labels: tensor([9, 5, 8, 7])
# Labels: tensor([3, 2, 8, 6])
# Labels: tensor([7, 4, 0, 8])
# Labels: tensor([1, 7, 3, 1])
# Labels: tensor([4, 8, 7, 9])
# Labels: tensor([9, 6, 2, 1])
# Labels: tensor([2, 2, 0, 3])
# Labels: tensor([6, 0, 1, 8])
# Labels: tensor([0, 2, 7, 2])
# Labels: tensor([0, 6, 8, 2])
# Labels: tensor([6, 0, 7, 8])
# Labels: tensor([6, 2, 0, 6])
# Labels: tensor([9, 7, 1, 2])
# Labels: tensor([7, 8, 2, 0])
# Labels: tensor([9, 3, 3, 1])
# Labels: tensor([4, 3, 9, 2])
# Labels: tensor([0, 9, 7, 5])
# Labels: tensor([3, 8, 4, 1])
# Labels: tensor([9, 7, 7, 7])
# Labels: tensor([8, 2, 7, 4])
# Labels: tensor([3, 9, 6, 1])
# Labels: tensor([1, 9, 5, 5])
# Labels: tensor([7, 6, 0, 9])
# Labels: tensor([8, 2, 1, 7])
# Labels: tensor([1, 4, 6, 1])
# Labels: tensor([3, 8, 8, 3])
# Labels: tensor([5, 5, 5, 8])
# Labels: tensor([9, 3, 7, 7])
# Labels: tensor([5, 9, 8, 3])
# Labels: tensor([7, 4, 7, 6])
# Labels: tensor([2, 4, 0, 7])
# Labels: tensor([3, 9, 7, 0])
# Labels: tensor([1, 5, 2, 6])
# Labels: tensor([0, 5, 3, 8])
# Labels: tensor([2, 3, 0, 0])
# Labels: tensor([1, 9, 8, 3])
# Labels: tensor([2, 2, 1, 4])
# Labels: tensor([7, 7, 5, 8])
# Labels: tensor([6, 7, 3, 7])
# Labels: tensor([4, 0, 8, 5])
# Labels: tensor([9, 9, 3, 0])
# Labels: tensor([3, 7, 0, 1])
# Labels: tensor([1, 8, 6, 3])
# Labels: tensor([0, 7, 5, 0])
# Labels: tensor([7, 8, 8, 0])
# Labels: tensor([5, 2, 3, 7])
# Labels: tensor([8, 7, 7, 7])
# Labels: tensor([4, 8, 6, 7])
# Labels: tensor([2, 8, 1, 0])
# Labels: tensor([7, 1, 4, 4])
# Labels: tensor([9, 3, 1, 6])
# Labels: tensor([0, 5, 3, 1])
# Labels: tensor([5, 2, 8, 6])
# Labels: tensor([6, 5, 3, 7])
# Labels: tensor([6, 1, 5, 8])
# Labels: tensor([9, 5, 0, 9])
# Labels: tensor([7, 6, 7, 2])
# Labels: tensor([3, 9, 7, 9])
# Labels: tensor([3, 0, 8, 5])
# Labels: tensor([1, 3, 8, 3])
# Labels: tensor([9, 4, 2, 1])
# Labels: tensor([3, 8, 2, 1])
# Labels: tensor([3, 3, 7, 0])
# Labels: tensor([7, 4, 8, 3])
# Labels: tensor([7, 5, 9, 9])
# Labels: tensor([4, 9, 7, 1])
# Labels: tensor([5, 2, 6, 2])
# Labels: tensor([1, 3, 8, 6])
# Labels: tensor([4, 2, 3, 9])
# Labels: tensor([5, 1, 7, 4])
# Labels: tensor([1, 8, 0, 9])
# Labels: tensor([1, 7, 3, 1])
# Labels: tensor([3, 4, 5, 5])
# Labels: tensor([5, 5, 7, 7])
# Labels: tensor([0, 9, 6, 7])
# Labels: tensor([2, 5, 7, 8])
# Labels: tensor([6, 3, 7, 6])
# Labels: tensor([3, 2, 0, 6])
# Labels: tensor([4, 2, 9, 4])
# Labels: tensor([2, 1, 6, 5])
# Labels: tensor([0, 1, 4, 1])
# Labels: tensor([9, 5, 3, 1])
# Labels: tensor([5, 2, 6, 3])
# Labels: tensor([3, 8, 2, 1])
# Labels: tensor([9, 7, 2, 9])
# Labels: tensor([9, 9, 6, 8])
# Labels: tensor([5, 1, 9, 8])
# Labels: tensor([7, 9, 3, 5])
# Labels: tensor([0, 3, 4, 8])
# Labels: tensor([8, 4, 2, 2])
# Labels: tensor([2, 5, 7, 2])
# Labels: tensor([8, 7, 0, 4])
# Labels: tensor([7, 7, 3, 4])
# Labels: tensor([5, 1, 6, 2])
# Labels: tensor([9, 9, 6, 1])
# Labels: tensor([6, 3, 9, 9])
# Labels: tensor([2, 4, 9, 1])
# Labels: tensor([7, 3, 6, 8])
# Labels: tensor([6, 7, 8, 4])
# Labels: tensor([3, 8, 6, 8])
# Labels: tensor([2, 4, 2, 3])
# Labels: tensor([3, 9, 6, 9])
# Labels: tensor([8, 9, 9, 0])
# Labels: tensor([1, 7, 9, 1])
# Labels: tensor([0, 2, 9, 7])
# Labels: tensor([9, 1, 1, 3])
# Labels: tensor([1, 1, 7, 2])
# Labels: tensor([7, 7, 6, 5])
# Labels: tensor([0, 9, 5, 8])
# Labels: tensor([1, 4, 4, 1])
# Labels: tensor([1, 7, 6, 4])
# Labels: tensor([0, 0, 9, 0])
# Labels: tensor([6, 6, 6, 0])
# Labels: tensor([7, 6, 3, 1])
# Labels: tensor([7, 3, 6, 8])
# Labels: tensor([2, 9, 8, 5])
# Labels: tensor([5, 4, 8, 1])
# Labels: tensor([4, 9, 2, 6])
# Labels: tensor([2, 7, 1, 1])
# Labels: tensor([2, 5, 6, 6])
# Labels: tensor([0, 3, 1, 2])
# Labels: tensor([3, 1, 4, 4])
# Labels: tensor([7, 7, 5, 5])
# Labels: tensor([0, 6, 6, 6])
# Labels: tensor([6, 8, 5, 6])
# Labels: tensor([8, 3, 8, 1])
# Labels: tensor([5, 5, 9, 6])
# Labels: tensor([4, 6, 1, 9])
# Labels: tensor([8, 0, 9, 1])
# Labels: tensor([0, 5, 2, 6])
# Labels: tensor([9, 9, 2, 3])
# Labels: tensor([5, 6, 9, 5])
# Labels: tensor([0, 5, 7, 0])
# Labels: tensor([1, 1, 9, 0])
# Labels: tensor([6, 2, 4, 5])
# Labels: tensor([9, 9, 7, 0])
# Labels: tensor([6, 3, 1, 6])
# Labels: tensor([5, 9, 9, 0])
# Labels: tensor([9, 3, 9, 0])
# Labels: tensor([8, 1, 1, 6])
# Labels: tensor([8, 3, 7, 3])
# Labels: tensor([2, 7, 8, 8])
# Labels: tensor([9, 9, 8, 3])
# Labels: tensor([7, 2, 4, 1])
# Labels: tensor([7, 1, 1, 8])
# Labels: tensor([0, 7, 8, 9])
# Labels: tensor([5, 7, 8, 3])
# Labels: tensor([2, 4, 0, 8])
# Labels: tensor([1, 3, 3, 8])
# Labels: tensor([0, 9, 8, 7])
# Labels: tensor([2, 1, 8, 6])
# Labels: tensor([7, 3, 0, 7])
# Labels: tensor([2, 8, 7, 3])
# Labels: tensor([5, 8, 3, 8])
# Labels: tensor([6, 8, 3, 5])
# Labels: tensor([6, 6, 1, 0])
# Labels: tensor([0, 2, 5, 2])
# Labels: tensor([1, 9, 0, 3])
# Labels: tensor([9, 4, 3, 6])
# Labels: tensor([5, 8, 0, 8])
# Labels: tensor([5, 7, 4, 3])
# Labels: tensor([4, 8, 5, 1])
# Labels: tensor([8, 1, 1, 6])
# Labels: tensor([7, 4, 5, 8])
# Labels: tensor([2, 1, 3, 7])
# Labels: tensor([7, 3, 6, 3])
# Labels: tensor([0, 8, 9, 9])
# Labels: tensor([2, 9, 2, 0])
# Labels: tensor([2, 9, 7, 9])
# Labels: tensor([2, 6, 5, 8])
# Labels: tensor([9, 7, 8, 9])
# Labels: tensor([7, 6, 6, 1])
# Labels: tensor([3, 7, 9, 6])
# Labels: tensor([4, 2, 6, 2])
# Labels: tensor([1, 7, 1, 1])
# Labels: tensor([9, 9, 7, 0])
# Labels: tensor([7, 6, 6, 5])
# Labels: tensor([5, 1, 7, 1])
# Labels: tensor([8, 3, 5, 8])
# Labels: tensor([5, 2, 7, 9])
# Labels: tensor([6, 1, 1, 3])
# Labels: tensor([1, 8, 7, 2])
# Labels: tensor([1, 8, 0, 6])
# Labels: tensor([9, 1, 2, 4])
# Labels: tensor([9, 3, 3, 9])
# Labels: tensor([3, 9, 4, 0])
# Labels: tensor([8, 6, 8, 2])
# Labels: tensor([7, 5, 6, 3])
# Labels: tensor([6, 7, 8, 1])
# Labels: tensor([2, 6, 2, 1])
# Labels: tensor([3, 9, 8, 4])
# Labels: tensor([6, 4, 8, 9])
# Labels: tensor([0, 5, 8, 3])
# Labels: tensor([4, 6, 5, 3])
# Labels: tensor([9, 1, 9, 1])
# Labels: tensor([2, 3, 0, 7])
# Labels: tensor([0, 7, 5, 7])
# Labels: tensor([2, 6, 2, 6])
# Labels: tensor([5, 5, 8, 8])
# Labels: tensor([7, 8, 7, 5])
# Labels: tensor([4, 2, 8, 6])
# Labels: tensor([8, 7, 2, 3])
# Labels: tensor([2, 2, 7, 0])
# Labels: tensor([2, 9, 5, 4])
# Labels: tensor([2, 9, 4, 1])
# Labels: tensor([3, 2, 5, 5])
# Labels: tensor([8, 2, 0, 4])
# Labels: tensor([1, 8, 6, 2])
# Labels: tensor([0, 9, 1, 6])
# Labels: tensor([8, 8, 8, 2])
# Labels: tensor([2, 2, 5, 6])
# Labels: tensor([2, 7, 2, 7])
# Labels: tensor([0, 2, 7, 1])
# Labels: tensor([5, 9, 6, 0])
# Labels: tensor([8, 9, 0, 9])
# Labels: tensor([4, 8, 3, 3])
# Labels: tensor([7, 1, 7, 2])
# Labels: tensor([5, 6, 0, 3])
# Labels: tensor([1, 7, 3, 1])
# Labels: tensor([5, 9, 8, 0])
# Labels: tensor([4, 0, 9, 0])
# Labels: tensor([6, 6, 4, 7])
# Labels: tensor([3, 9, 5, 4])
# Labels: tensor([1, 7, 0, 5])
# Labels: tensor([3, 1, 0, 1])
# Labels: tensor([0, 1, 1, 4])
# Labels: tensor([2, 4, 5, 8])
# Labels: tensor([9, 9, 1, 6])
# Labels: tensor([1, 6, 3, 4])
# Labels: tensor([2, 0, 1, 8])
# Labels: tensor([4, 9, 6, 5])
# Labels: tensor([2, 5, 4, 8])
# Labels: tensor([6, 5, 7, 0])
# Labels: tensor([9, 4, 9, 6])
# Labels: tensor([3, 9, 9, 1])
# Labels: tensor([4, 9, 0, 6])
# Labels: tensor([7, 4, 9, 1])
# Labels: tensor([7, 8, 6, 5])
# Labels: tensor([8, 3, 9, 9])
# Labels: tensor([5, 9, 2, 6])
# Labels: tensor([6, 2, 6, 8])
# Labels: tensor([2, 6, 8, 2])
# Labels: tensor([5, 0, 6, 6])
# Labels: tensor([4, 6, 4, 6])
# Labels: tensor([2, 5, 2, 6])
# Labels: tensor([8, 7, 2, 3])
# Labels: tensor([2, 3, 3, 6])
# Labels: tensor([7, 5, 2, 3])
# Labels: tensor([0, 9, 6, 6])
# Labels: tensor([5, 0, 2, 1])
# Labels: tensor([4, 1, 0, 4])
# Labels: tensor([7, 0, 6, 1])
# Labels: tensor([7, 3, 9, 9])
# Labels: tensor([7, 7, 2, 5])
# Labels: tensor([2, 2, 6, 7])
# Labels: tensor([0, 8, 1, 6])
# Labels: tensor([1, 6, 5, 8])
# Labels: tensor([1, 4, 1, 6])
# Labels: tensor([4, 7, 1, 8])
# Labels: tensor([4, 7, 9, 1])
# Labels: tensor([8, 7, 7, 9])
# Labels: tensor([6, 9, 1, 3])
# Labels: tensor([1, 6, 4, 5])
# Labels: tensor([8, 2, 6, 4])
# Labels: tensor([8, 9, 2, 5])
# Labels: tensor([4, 9, 2, 8])
# Labels: tensor([3, 5, 7, 9])
# Labels: tensor([5, 2, 0, 6])
# Labels: tensor([2, 3, 2, 9])
# Labels: tensor([4, 8, 9, 2])
# Labels: tensor([2, 5, 8, 6])
# Labels: tensor([4, 5, 1, 9])
# Labels: tensor([2, 5, 2, 2])
# Labels: tensor([8, 5, 2, 5])
# Labels: tensor([0, 9, 1, 2])
# Labels: tensor([0, 9, 2, 4])
# Labels: tensor([3, 0, 2, 6])
# Labels: tensor([2, 2, 4, 7])
# Labels: tensor([3, 4, 8, 7])
# Labels: tensor([5, 9, 2, 4])
# Labels: tensor([9, 6, 8, 1])
# Labels: tensor([4, 0, 8, 4])
# Labels: tensor([2, 2, 9, 9])
# Labels: tensor([1, 3, 8, 0])
# Labels: tensor([6, 7, 7, 9])
# Labels: tensor([7, 3, 6, 3])
# Labels: tensor([6, 0, 3, 1])
# Labels: tensor([3, 8, 6, 3])
# Labels: tensor([5, 9, 6, 0])
# Labels: tensor([6, 2, 0, 6])
# Labels: tensor([6, 6, 5, 2])
# Labels: tensor([8, 4, 4, 3])
# Labels: tensor([3, 2, 3, 0])
# Labels: tensor([8, 3, 9, 2])
# Labels: tensor([0, 6, 1, 1])
# Labels: tensor([9, 2, 1, 6])
# Labels: tensor([4, 4, 4, 8])
# Labels: tensor([1, 6, 6, 6])
# Labels: tensor([1, 3, 9, 1])
# Labels: tensor([0, 9, 5, 1])
# Labels: tensor([4, 9, 8, 3])
# Labels: tensor([5, 8, 1, 9])
# Labels: tensor([2, 7, 5, 8])
# Labels: tensor([3, 2, 0, 0])
# Labels: tensor([2, 2, 8, 1])
# Labels: tensor([1, 6, 2, 0])
# Labels: tensor([4, 4, 1, 1])
# Labels: tensor([2, 5, 1, 7])
# Labels: tensor([2, 4, 6, 1])
# Labels: tensor([9, 6, 0, 2])
# Labels: tensor([1, 7, 7, 4])
# Labels: tensor([5, 9, 2, 7])
# Labels: tensor([0, 8, 5, 9])
# Labels: tensor([0, 6, 6, 8])
# Labels: tensor([2, 0, 5, 0])
# Labels: tensor([0, 0, 0, 5])
# Labels: tensor([7, 5, 3, 9])
# Labels: tensor([5, 6, 0, 6])
# Labels: tensor([9, 6, 2, 9])
# Labels: tensor([7, 8, 7, 5])
# Labels: tensor([0, 5, 6, 4])
# Labels: tensor([7, 9, 3, 3])
# Labels: tensor([9, 2, 0, 8])
# Labels: tensor([4, 0, 2, 7])
# Labels: tensor([9, 1, 0, 7])
# Labels: tensor([8, 7, 4, 1])
# Labels: tensor([1, 1, 9, 7])
# Labels: tensor([6, 6, 1, 4])
# Labels: tensor([0, 9, 7, 4])
# Labels: tensor([1, 1, 3, 7])
# Labels: tensor([9, 8, 1, 1])
# Labels: tensor([6, 8, 2, 0])
# Labels: tensor([8, 0, 6, 9])
# Labels: tensor([6, 7, 9, 5])
# Labels: tensor([8, 0, 4, 9])
# Labels: tensor([3, 5, 9, 3])
# Labels: tensor([9, 0, 1, 8])
# Labels: tensor([0, 2, 1, 0])
# Labels: tensor([1, 0, 7, 1])
# Labels: tensor([7, 1, 3, 5])
# Labels: tensor([3, 1, 2, 6])
# Labels: tensor([4, 0, 9, 9])
# Labels: tensor([4, 0, 7, 4])
# Labels: tensor([8, 4, 8, 2])
# Labels: tensor([6, 6, 2, 0])
# Labels: tensor([5, 7, 8, 2])
# Labels: tensor([7, 2, 6, 7])
# Labels: tensor([3, 9, 1, 7])
# Labels: tensor([6, 7, 3, 2])
# Labels: tensor([4, 2, 7, 8])
# Labels: tensor([8, 0, 1, 7])
# Labels: tensor([7, 7, 8, 9])
# Labels: tensor([1, 4, 5, 4])
# Labels: tensor([0, 3, 3, 1])
# Labels: tensor([6, 0, 6, 8])
# Labels: tensor([4, 3, 4, 8])
# Labels: tensor([8, 1, 6, 4])
# Labels: tensor([5, 6, 8, 8])
# Labels: tensor([0, 9, 3, 3])
# Labels: tensor([0, 1, 3, 2])
# Labels: tensor([6, 4, 5, 6])
# Labels: tensor([3, 0, 0, 3])
# Labels: tensor([4, 7, 9, 4])
# Labels: tensor([8, 2, 6, 9])
# Labels: tensor([8, 5, 9, 8])
# Labels: tensor([6, 5, 6, 8])
# Labels: tensor([7, 7, 4, 1])
# Labels: tensor([1, 9, 8, 0])
# Labels: tensor([0, 9, 4, 9])
# Labels: tensor([7, 2, 9, 3])
# Labels: tensor([5, 9, 8, 3])
# Labels: tensor([3, 3, 1, 6])
# Labels: tensor([0, 2, 5, 1])
# Labels: tensor([3, 9, 8, 5])
# Labels: tensor([8, 2, 7, 5])
# Labels: tensor([3, 7, 9, 3])
# Labels: tensor([6, 4, 3, 8])
# Labels: tensor([5, 6, 2, 8])
# Labels: tensor([4, 0, 4, 1])
# Labels: tensor([5, 8, 7, 6])
# Labels: tensor([4, 9, 0, 2])
# Labels: tensor([3, 8, 3, 8])
# Labels: tensor([6, 5, 1, 8])
# Labels: tensor([1, 4, 6, 4])
# Labels: tensor([0, 6, 1, 8])
# Labels: tensor([0, 7, 9, 8])
# Labels: tensor([2, 4, 9, 5])
# Labels: tensor([9, 5, 4, 6])
# Labels: tensor([1, 9, 1, 4])
# Labels: tensor([5, 6, 9, 0])
# Labels: tensor([5, 6, 9, 0])
# Labels: tensor([6, 7, 1, 5])
# Labels: tensor([5, 3, 4, 1])
# Labels: tensor([1, 8, 4, 3])
# Labels: tensor([7, 5, 1, 3])
# Labels: tensor([1, 5, 0, 6])
# Labels: tensor([4, 5, 0, 6])
# Labels: tensor([8, 3, 6, 5])
# Labels: tensor([4, 0, 6, 5])
# Labels: tensor([7, 4, 9, 0])
# Labels: tensor([6, 2, 5, 5])
# Labels: tensor([3, 0, 5, 2])
# Labels: tensor([7, 8, 1, 0])
# Labels: tensor([3, 5, 4, 1])
# Labels: tensor([6, 6, 0, 0])
# Labels: tensor([3, 3, 2, 1])
# Labels: tensor([4, 1, 0, 6])
# Labels: tensor([0, 1, 1, 6])
# Labels: tensor([0, 9, 8, 3])
# Labels: tensor([8, 9, 2, 4])
# Labels: tensor([1, 4, 9, 2])
# Labels: tensor([5, 2, 2, 3])
# Labels: tensor([8, 2, 7, 7])
# Labels: tensor([7, 0, 3, 5])
# Labels: tensor([5, 4, 3, 5])
# Labels: tensor([3, 7, 5, 2])
# Labels: tensor([2, 4, 3, 4])
# Labels: tensor([5, 1, 4, 3])
# Labels: tensor([0, 6, 0, 4])
# Labels: tensor([1, 4, 3, 8])
# Labels: tensor([1, 2, 6, 5])
# Labels: tensor([7, 5, 4, 2])
# Labels: tensor([3, 3, 8, 9])
# Labels: tensor([1, 1, 9, 4])
# Labels: tensor([3, 9, 2, 5])
# Labels: tensor([5, 1, 1, 4])
# Labels: tensor([3, 7, 9, 3])
# Labels: tensor([4, 4, 4, 9])
# Labels: tensor([0, 8, 3, 3])
# Labels: tensor([6, 9, 0, 7])
# Labels: tensor([0, 9, 5, 1])
# Labels: tensor([2, 4, 0, 2])
# Labels: tensor([5, 8, 0, 5])
# Labels: tensor([3, 8, 0, 5])
# Labels: tensor([0, 1, 3, 1])
# Labels: tensor([8, 8, 2, 7])
# Labels: tensor([1, 4, 2, 0])
# Labels: tensor([0, 4, 5, 5])
# Labels: tensor([1, 3, 5, 0])
# Labels: tensor([1, 1, 9, 7])
# Labels: tensor([2, 2, 5, 3])
# Labels: tensor([0, 1, 3, 2])
# Labels: tensor([5, 7, 8, 0])
# Labels: tensor([1, 5, 5, 5])
# Labels: tensor([8, 0, 3, 7])
# Labels: tensor([5, 1, 6, 0])
# Labels: tensor([2, 1, 9, 1])
# Labels: tensor([4, 0, 5, 7])
# Labels: tensor([2, 8, 1, 6])
# Labels: tensor([5, 4, 0, 5])
# Labels: tensor([0, 9, 0, 5])
# Labels: tensor([4, 5, 4, 4])
# Labels: tensor([1, 9, 7, 1])
# Labels: tensor([5, 1, 6, 4])
# Labels: tensor([1, 1, 2, 9])
# Labels: tensor([5, 5, 4, 5])
# Labels: tensor([2, 9, 0, 2])
# Labels: tensor([8, 4, 7, 0])
# Labels: tensor([8, 8, 8, 5])
# Labels: tensor([8, 9, 6, 3])
# Labels: tensor([1, 6, 7, 2])
# Labels: tensor([0, 5, 1, 4])
# Labels: tensor([9, 2, 4, 7])
# Labels: tensor([0, 3, 9, 8])
# Labels: tensor([2, 4, 8, 6])
# Labels: tensor([4, 1, 0, 7])
# Labels: tensor([0, 9, 3, 8])
# Labels: tensor([2, 7, 8, 8])
# Labels: tensor([1, 4, 6, 0])
# Labels: tensor([2, 1, 4, 6])
# Labels: tensor([7, 5, 0, 5])
# Labels: tensor([3, 0, 9, 3])
# Labels: tensor([7, 8, 2, 3])
# Labels: tensor([0, 8, 4, 5])
# Labels: tensor([1, 3, 5, 9])
# Labels: tensor([5, 1, 6, 9])
# Labels: tensor([5, 4, 3, 4])
# Labels: tensor([0, 3, 1, 3])
# Labels: tensor([0, 8, 9, 7])
# Labels: tensor([0, 6, 2, 9])
# Labels: tensor([5, 6, 2, 1])
# Labels: tensor([5, 3, 9, 9])
# Labels: tensor([4, 4, 2, 1])
# Labels: tensor([4, 8, 1, 7])
# Labels: tensor([7, 5, 8, 4])
# Labels: tensor([7, 3, 3, 6])
# Labels: tensor([0, 8, 8, 1])
# Labels: tensor([0, 2, 9, 5])
# Labels: tensor([3, 9, 6, 7])
# Labels: tensor([9, 0, 2, 9])
# Labels: tensor([2, 3, 8, 7])
# Labels: tensor([0, 8, 4, 8])
# Labels: tensor([0, 3, 4, 7])
# Labels: tensor([1, 6, 4, 7])
# Labels: tensor([9, 3, 9, 2])
# Labels: tensor([3, 4, 9, 6])
# Labels: tensor([8, 2, 0, 2])
# Labels: tensor([8, 4, 5, 2])
# Labels: tensor([3, 0, 3, 9])
# Labels: tensor([4, 3, 0, 1])
# Labels: tensor([5, 6, 6, 4])
# Labels: tensor([9, 1, 0, 8])
# Labels: tensor([7, 8, 1, 9])
# Labels: tensor([3, 2, 6, 2])
# Labels: tensor([8, 8, 2, 3])
# Labels: tensor([7, 3, 1, 1])
# Labels: tensor([3, 7, 7, 8])
# Labels: tensor([4, 2, 6, 6])
# Labels: tensor([6, 9, 1, 7])
# Labels: tensor([5, 7, 2, 2])
# Labels: tensor([0, 8, 7, 1])
# Labels: tensor([6, 1, 1, 2])
# Labels: tensor([8, 1, 3, 3])
# Labels: tensor([2, 3, 3, 3])
# Labels: tensor([7, 3, 8, 6])
# Labels: tensor([3, 7, 6, 1])
# Labels: tensor([0, 1, 4, 4])
# Labels: tensor([2, 1, 9, 1])
# Labels: tensor([5, 3, 5, 5])
# Labels: tensor([4, 8, 3, 5])
# Labels: tensor([5, 5, 8, 0])
# Labels: tensor([3, 6, 0, 4])
# Labels: tensor([1, 4, 4, 7])
# Labels: tensor([3, 0, 7, 9])
# Labels: tensor([9, 1, 7, 4])
# Labels: tensor([6, 7, 2, 1])
# Labels: tensor([0, 2, 3, 6])
# Labels: tensor([9, 0, 3, 8])
# Labels: tensor([1, 5, 6, 1])
# Labels: tensor([0, 4, 9, 9])
# Labels: tensor([9, 5, 6, 3])
# Labels: tensor([2, 9, 8, 8])
# Labels: tensor([2, 1, 7, 1])
# Labels: tensor([5, 1, 7, 7])
# Labels: tensor([8, 9, 7, 1])
# Labels: tensor([6, 3, 5, 3])
# Labels: tensor([3, 1, 0, 0])
# Labels: tensor([8, 3, 9, 6])
# Labels: tensor([9, 8, 2, 6])
# Labels: tensor([8, 1, 4, 2])
# Labels: tensor([6, 9, 6, 0])
# Labels: tensor([3, 1, 1, 9])
# Labels: tensor([0, 2, 4, 0])
# Labels: tensor([6, 2, 2, 0])
# Labels: tensor([7, 6, 9, 6])
# Labels: tensor([8, 4, 7, 9])
# Labels: tensor([0, 6, 2, 6])
# Labels: tensor([0, 6, 5, 6])
# Labels: tensor([5, 7, 2, 5])
# Labels: tensor([9, 4, 7, 4])
# Labels: tensor([6, 4, 9, 1])
# Labels: tensor([4, 6, 2, 5])
# Labels: tensor([4, 7, 2, 1])
# Labels: tensor([7, 3, 6, 2])
# Labels: tensor([4, 6, 6, 2])
# Labels: tensor([1, 7, 4, 6])
# Labels: tensor([5, 3, 2, 5])
# Labels: tensor([6, 8, 6, 5])
# Labels: tensor([4, 3, 1, 8])
# Labels: tensor([3, 2, 8, 6])
# Labels: tensor([0, 2, 0, 9])
# Labels: tensor([3, 4, 6, 1])
# Labels: tensor([4, 1, 4, 1])
# Labels: tensor([3, 1, 2, 0])
# Labels: tensor([3, 1, 5, 0])
# Labels: tensor([3, 8, 4, 0])
# Labels: tensor([3, 5, 0, 9])
# Labels: tensor([0, 1, 2, 4])
# Labels: tensor([6, 8, 5, 2])
# Labels: tensor([5, 1, 2, 5])
# Labels: tensor([4, 1, 6, 8])
# Labels: tensor([2, 6, 5, 8])
# Labels: tensor([9, 7, 1, 8])
# Labels: tensor([4, 4, 9, 7])
# Labels: tensor([7, 8, 2, 9])
# Labels: tensor([0, 1, 5, 3])
# Labels: tensor([9, 0, 7, 4])
# Labels: tensor([1, 8, 6, 6])
# Labels: tensor([5, 2, 0, 3])
# Labels: tensor([7, 7, 0, 4])
# Labels: tensor([6, 2, 3, 9])
# Labels: tensor([4, 8, 6, 1])
# Labels: tensor([2, 4, 4, 2])
# Labels: tensor([2, 5, 9, 1])
# Labels: tensor([9, 5, 3, 0])
# Labels: tensor([8, 5, 1, 1])
# Labels: tensor([6, 2, 2, 5])
# Labels: tensor([9, 6, 7, 4])
# Labels: tensor([4, 6, 7, 8])
# Labels: tensor([8, 2, 4, 4])
# Labels: tensor([8, 4, 8, 0])
# Labels: tensor([1, 3, 0, 6])
# Labels: tensor([7, 7, 0, 7])
# Labels: tensor([3, 3, 7, 7])
# Labels: tensor([0, 3, 3, 2])
# Labels: tensor([8, 7, 7, 4])
# Labels: tensor([2, 5, 1, 1])
# Labels: tensor([7, 9, 8, 1])
# Labels: tensor([0, 6, 5, 5])
# Labels: tensor([8, 2, 6, 2])
# Labels: tensor([3, 4, 5, 5])
# Labels: tensor([1, 5, 8, 5])
# Labels: tensor([8, 3, 2, 7])
# Labels: tensor([4, 2, 1, 1])
# Labels: tensor([1, 1, 3, 2])
# Labels: tensor([4, 3, 9, 7])
# Labels: tensor([6, 9, 7, 7])
# Labels: tensor([6, 3, 7, 7])
# Labels: tensor([1, 6, 4, 3])
# Labels: tensor([0, 1, 0, 7])
# Labels: tensor([4, 3, 6, 5])
# Labels: tensor([2, 2, 7, 0])
# Labels: tensor([3, 7, 4, 1])
# Labels: tensor([0, 7, 4, 3])
# Labels: tensor([1, 9, 5, 3])
# Labels: tensor([3, 4, 1, 5])
# Labels: tensor([8, 3, 7, 6])
# Labels: tensor([9, 3, 6, 2])
# Labels: tensor([1, 8, 2, 4])
# Labels: tensor([8, 5, 4, 5])
# Labels: tensor([2, 1, 3, 3])
# Labels: tensor([3, 7, 9, 4])
# Labels: tensor([3, 8, 1, 0])
# Labels: tensor([8, 8, 8, 5])
# Labels: tensor([0, 2, 3, 0])
# Labels: tensor([3, 3, 8, 7])
# Labels: tensor([2, 7, 8, 9])
# Labels: tensor([0, 2, 8, 1])
# Labels: tensor([5, 1, 0, 0])
# Labels: tensor([2, 7, 0, 5])
# Labels: tensor([1, 1, 3, 0])
# Labels: tensor([9, 1, 1, 1])
# Labels: tensor([1, 2, 8, 8])
# Labels: tensor([6, 3, 9, 5])
# Labels: tensor([5, 1, 8, 7])
# Labels: tensor([7, 9, 2, 0])
# Labels: tensor([2, 1, 8, 0])
# Labels: tensor([1, 6, 9, 9])
# Labels: tensor([1, 1, 2, 1])
# Labels: tensor([5, 9, 7, 8])
# Labels: tensor([0, 7, 3, 8])
# Labels: tensor([6, 0, 7, 1])
# Labels: tensor([2, 8, 5, 7])
# Labels: tensor([2, 1, 3, 4])
# Labels: tensor([4, 6, 4, 0])
# Labels: tensor([6, 8, 2, 9])
# Labels: tensor([0, 2, 4, 1])
# Labels: tensor([0, 4, 9, 8])
# Labels: tensor([8, 6, 7, 8])
# Labels: tensor([9, 0, 4, 1])
# Labels: tensor([8, 8, 6, 7])
# Labels: tensor([3, 5, 9, 7])
# Labels: tensor([7, 3, 9, 0])
# Labels: tensor([8, 0, 3, 6])
# Labels: tensor([0, 7, 4, 2])
# Labels: tensor([2, 8, 0, 5])
# Labels: tensor([4, 6, 2, 9])
# Labels: tensor([5, 0, 6, 7])
# Labels: tensor([8, 1, 5, 7])
# Labels: tensor([6, 3, 3, 6])
# Labels: tensor([5, 6, 9, 5])
# Labels: tensor([7, 0, 1, 5])
# Labels: tensor([6, 1, 6, 1])
# Labels: tensor([5, 6, 2, 8])
# Labels: tensor([3, 9, 0, 9])
# Labels: tensor([3, 6, 4, 7])
# Labels: tensor([8, 2, 9, 4])
# Labels: tensor([7, 9, 3, 9])
# Labels: tensor([2, 6, 7, 7])
# Labels: tensor([1, 6, 7, 1])
# Labels: tensor([1, 3, 0, 1])
# Labels: tensor([1, 3, 9, 1])
# Labels: tensor([8, 4, 9, 0])
# Labels: tensor([9, 8, 5, 9])
# Labels: tensor([4, 9, 2, 0])
# Labels: tensor([9, 6, 8, 8])
# Labels: tensor([2, 2, 7, 2])
# Labels: tensor([1, 2, 7, 9])
# Labels: tensor([9, 4, 0, 3])
# Labels: tensor([3, 7, 8, 7])
# Labels: tensor([0, 9, 8, 0])
# Labels: tensor([5, 2, 4, 4])
# Labels: tensor([2, 0, 7, 9])
# Labels: tensor([9, 3, 6, 3])
# Labels: tensor([7, 4, 2, 3])
# Labels: tensor([9, 0, 1, 7])
# Labels: tensor([5, 4, 3, 7])
# Labels: tensor([2, 9, 7, 5])
# Labels: tensor([2, 0, 3, 7])
# Labels: tensor([7, 4, 8, 0])
# Labels: tensor([4, 1, 9, 1])
# Labels: tensor([5, 7, 7, 5])
# Labels: tensor([0, 6, 6, 3])
# Labels: tensor([0, 8, 5, 7])
# Labels: tensor([6, 0, 3, 2])
# Labels: tensor([2, 3, 6, 1])
# Labels: tensor([4, 5, 2, 5])
# Labels: tensor([7, 1, 5, 6])
# Labels: tensor([4, 6, 5, 3])
# Labels: tensor([1, 4, 3, 3])
# Labels: tensor([6, 1, 2, 6])
# Labels: tensor([8, 8, 7, 1])
# Labels: tensor([3, 0, 3, 7])
# Labels: tensor([9, 8, 9, 3])
# Labels: tensor([1, 4, 6, 2])
# Labels: tensor([9, 4, 3, 1])
# Labels: tensor([8, 4, 7, 8])
# Labels: tensor([8, 2, 5, 8])
# Labels: tensor([0, 3, 9, 8])
# Labels: tensor([8, 0, 9, 0])
# Labels: tensor([6, 0, 5, 0])
# Labels: tensor([8, 9, 0, 2])
# Labels: tensor([2, 4, 7, 8])
# Labels: tensor([3, 9, 8, 9])
# Labels: tensor([3, 6, 9, 5])
# Labels: tensor([6, 6, 6, 7])
# Labels: tensor([7, 0, 9, 8])
# Labels: tensor([8, 4, 2, 1])
# Labels: tensor([8, 5, 2, 5])
# Labels: tensor([1, 3, 4, 7])
# Labels: tensor([6, 7, 5, 1])
# Labels: tensor([2, 0, 8, 5])
# Labels: tensor([2, 1, 2, 3])
# Labels: tensor([5, 0, 3, 4])
# Labels: tensor([8, 6, 0, 5])
# Labels: tensor([0, 7, 3, 3])
# Labels: tensor([4, 4, 7, 5])
# Labels: tensor([5, 9, 4, 8])
# Labels: tensor([5, 8, 1, 7])
# Labels: tensor([7, 0, 1, 8])
# Labels: tensor([2, 9, 7, 1])
# Labels: tensor([4, 2, 2, 0])
# Labels: tensor([9, 4, 6, 4])
# Labels: tensor([9, 2, 2, 2])
# Labels: tensor([4, 1, 4, 5])
# Labels: tensor([1, 4, 2, 4])
# Labels: tensor([4, 0, 7, 1])
# Labels: tensor([3, 4, 8, 3])
# Labels: tensor([1, 4, 6, 0])
# Labels: tensor([7, 4, 0, 4])
# Labels: tensor([6, 5, 8, 2])
# Labels: tensor([7, 7, 0, 8])
# Labels: tensor([2, 8, 4, 1])
# Labels: tensor([2, 8, 2, 8])
# Labels: tensor([1, 1, 7, 0])
# Labels: tensor([7, 3, 0, 5])
# Labels: tensor([2, 2, 0, 1])
# Labels: tensor([1, 7, 9, 3])
# Labels: tensor([8, 0, 1, 0])
# Labels: tensor([5, 0, 0, 2])
# Labels: tensor([9, 7, 0, 4])
# Labels: tensor([0, 6, 9, 1])
# Labels: tensor([9, 3, 1, 4])
# Labels: tensor([2, 8, 3, 2])
# Labels: tensor([7, 2, 3, 3])
# Labels: tensor([5, 0, 0, 4])
# Labels: tensor([7, 0, 2, 4])
# Labels: tensor([1, 8, 8, 2])
# Labels: tensor([1, 0, 4, 4])
# Labels: tensor([4, 0, 3, 7])
# Labels: tensor([7, 6, 3, 2])
# Labels: tensor([3, 5, 7, 6])
# Labels: tensor([0, 1, 2, 3])
# Labels: tensor([9, 4, 0, 6])
# Labels: tensor([2, 8, 4, 4])
# Labels: tensor([4, 1, 3, 2])
# Labels: tensor([1, 0, 8, 2])
# Labels: tensor([0, 4, 9, 5])
# Labels: tensor([2, 4, 3, 8])
# Labels: tensor([1, 4, 5, 3])
# Labels: tensor([8, 4, 8, 7])
# Labels: tensor([3, 8, 7, 1])
# Labels: tensor([3, 6, 9, 1])
# Labels: tensor([6, 3, 9, 9])
# Labels: tensor([5, 4, 5, 2])
# Labels: tensor([2, 1, 4, 2])
# Labels: tensor([4, 7, 7, 4])
# Labels: tensor([1, 0, 8, 3])
# Labels: tensor([3, 4, 5, 9])
# Labels: tensor([2, 6, 9, 0])
# Labels: tensor([6, 9, 1, 3])
# Labels: tensor([0, 7, 5, 1])
# Labels: tensor([8, 5, 2, 9])
# Labels: tensor([6, 3, 6, 5])
# Labels: tensor([6, 3, 1, 0])
# Labels: tensor([7, 1, 6, 2])
# Labels: tensor([9, 5, 6, 0])
# Labels: tensor([1, 6, 2, 6])
# Labels: tensor([0, 4, 7, 5])
# Labels: tensor([8, 2, 9, 3])
# Labels: tensor([8, 9, 5, 3])
# Labels: tensor([8, 4, 2, 4])
# Labels: tensor([2, 5, 6, 2])
# Labels: tensor([2, 9, 5, 3])
# Labels: tensor([3, 1, 4, 7])
# Labels: tensor([3, 4, 5, 6])
# Labels: tensor([7, 9, 7, 9])
# Labels: tensor([4, 7, 5, 7])
# Labels: tensor([8, 8, 5, 6])
# Labels: tensor([8, 1, 8, 0])
# Labels: tensor([4, 6, 8, 8])
# Labels: tensor([5, 7, 2, 6])
# Labels: tensor([3, 3, 4, 4])
# Labels: tensor([0, 3, 7, 9])
# Labels: tensor([1, 3, 3, 4])
# Labels: tensor([4, 7, 6, 7])
# Labels: tensor([0, 1, 7, 2])
# Labels: tensor([1, 3, 8, 2])
# Labels: tensor([0, 7, 9, 0])
# Labels: tensor([2, 5, 8, 7])
# Labels: tensor([6, 5, 5, 6])
# Labels: tensor([8, 7, 0, 2])
# Labels: tensor([0, 0, 5, 5])
# Labels: tensor([1, 9, 9, 2])
# Labels: tensor([2, 7, 2, 8])
# Labels: tensor([5, 1, 6, 2])
# Labels: tensor([8, 9, 7, 2])
# Labels: tensor([6, 4, 1, 5])
# Labels: tensor([2, 1, 8, 2])
# Labels: tensor([0, 2, 5, 7])
# Labels: tensor([3, 6, 5, 8])
# Labels: tensor([8, 9, 6, 4])
# Labels: tensor([5, 6, 3, 7])
# Labels: tensor([3, 6, 6, 3])
# Labels: tensor([0, 6, 5, 7])
# Labels: tensor([6, 4, 6, 4])
# Labels: tensor([8, 3, 2, 0])
# Labels: tensor([0, 5, 5, 3])
# Labels: tensor([5, 9, 2, 2])
# Labels: tensor([0, 4, 8, 4])
# Labels: tensor([8, 0, 0, 6])
# Labels: tensor([1, 6, 6, 0])
# Labels: tensor([7, 7, 5, 3])
# Labels: tensor([6, 7, 1, 0])
# Labels: tensor([2, 6, 9, 5])
# Labels: tensor([9, 4, 7, 0])
# Labels: tensor([9, 1, 4, 6])
# Labels: tensor([5, 7, 4, 1])
# Labels: tensor([7, 5, 4, 5])
# Labels: tensor([5, 9, 5, 3])
# Labels: tensor([4, 2, 3, 8])
# Labels: tensor([1, 9, 2, 3])
# Labels: tensor([4, 8, 2, 7])
# Labels: tensor([5, 5, 0, 7])
# Labels: tensor([0, 8, 8, 0])
# Labels: tensor([4, 5, 0, 3])
# Labels: tensor([9, 0, 6, 3])
# Labels: tensor([2, 0, 7, 8])
# Labels: tensor([3, 2, 2, 9])
# Labels: tensor([2, 3, 4, 7])
# Labels: tensor([8, 1, 8, 0])
# Labels: tensor([8, 3, 5, 1])
# Labels: tensor([5, 7, 8, 6])
# Labels: tensor([4, 9, 7, 4])
# Labels: tensor([4, 7, 2, 2])
# Labels: tensor([5, 3, 6, 2])
# Labels: tensor([8, 1, 1, 6])
# Labels: tensor([9, 4, 5, 6])
# Labels: tensor([5, 5, 3, 6])
# Labels: tensor([4, 9, 9, 5])
# Labels: tensor([9, 6, 0, 9])
# Labels: tensor([2, 4, 2, 9])
# Labels: tensor([6, 0, 4, 1])
# Labels: tensor([0, 7, 5, 8])
# Labels: tensor([3, 1, 4, 4])
# Labels: tensor([0, 0, 8, 9])
# Labels: tensor([1, 8, 0, 3])
# Labels: tensor([3, 9, 9, 3])
# Labels: tensor([8, 2, 9, 1])
# Labels: tensor([6, 9, 4, 0])
# Labels: tensor([9, 9, 9, 1])
# Labels: tensor([4, 6, 9, 9])
# Labels: tensor([7, 2, 8, 1])
# Labels: tensor([4, 9, 0, 7])
# Labels: tensor([4, 1, 7, 3])
# Labels: tensor([2, 6, 2, 8])
# Labels: tensor([2, 2, 0, 8])
# Labels: tensor([2, 3, 1, 7])
# Labels: tensor([3, 3, 5, 3])
# Labels: tensor([8, 2, 0, 1])
# Labels: tensor([2, 6, 0, 8])
# Labels: tensor([5, 3, 7, 6])
# Labels: tensor([0, 7, 1, 6])
# Labels: tensor([9, 6, 0, 9])
# Labels: tensor([1, 6, 5, 0])
# Labels: tensor([7, 1, 9, 3])
# Labels: tensor([0, 0, 1, 2])
# Labels: tensor([5, 5, 4, 8])
# Labels: tensor([0, 5, 3, 6])
# Labels: tensor([4, 2, 2, 4])
# Labels: tensor([2, 9, 6, 7])
# Labels: tensor([8, 4, 0, 1])
# Labels: tensor([6, 4, 0, 4])
# Labels: tensor([9, 9, 7, 0])
# Labels: tensor([0, 0, 2, 8])
# Labels: tensor([8, 5, 6, 7])
# Labels: tensor([7, 6, 0, 1])
# Labels: tensor([7, 7, 3, 8])
# Labels: tensor([0, 3, 9, 8])
# Labels: tensor([3, 3, 1, 2])
# Labels: tensor([2, 6, 0, 5])
# Labels: tensor([5, 2, 3, 3])
# Labels: tensor([3, 2, 0, 5])
# Labels: tensor([7, 2, 0, 9])
# Labels: tensor([1, 9, 7, 9])
# Labels: tensor([5, 8, 9, 3])
# Labels: tensor([6, 2, 3, 3])
# Labels: tensor([6, 5, 2, 5])
# Labels: tensor([9, 0, 6, 9])
# Labels: tensor([9, 6, 7, 6])
# Labels: tensor([2, 5, 2, 2])
# Labels: tensor([9, 0, 0, 9])
# Labels: tensor([1, 8, 1, 8])
# Labels: tensor([8, 7, 1, 7])
# Labels: tensor([5, 8, 1, 5])
# Labels: tensor([6, 8, 2, 0])
# Labels: tensor([7, 7, 6, 4])
# Labels: tensor([9, 0, 4, 5])
# Labels: tensor([9, 0, 5, 0])
# Labels: tensor([9, 2, 8, 2])
# Labels: tensor([4, 7, 4, 6])
# Labels: tensor([3, 1, 4, 1])
# Labels: tensor([3, 1, 9, 9])
# Labels: tensor([6, 3, 6, 7])
# Labels: tensor([6, 0, 8, 7])
# Labels: tensor([5, 4, 7, 5])
# Labels: tensor([9, 2, 1, 9])
# Labels: tensor([4, 1, 2, 5])
# Labels: tensor([0, 5, 6, 6])
# Labels: tensor([5, 9, 5, 9])
# Labels: tensor([7, 9, 3, 2])
# Labels: tensor([5, 5, 0, 6])
# Labels: tensor([5, 6, 7, 8])
# Labels: tensor([4, 8, 9, 6])
# Labels: tensor([4, 1, 2, 8])
# Labels: tensor([0, 6, 2, 7])
# Labels: tensor([2, 3, 2, 2])
# Labels: tensor([4, 7, 7, 6])
# Labels: tensor([4, 3, 6, 8])
# Labels: tensor([3, 7, 3, 5])
# Labels: tensor([6, 3, 4, 0])
# Labels: tensor([4, 2, 5, 5])
# Labels: tensor([8, 5, 5, 8])
# Labels: tensor([0, 6, 4, 6])
# Labels: tensor([0, 7, 9, 3])
# Labels: tensor([6, 0, 1, 3])
# Labels: tensor([2, 2, 4, 9])
# Labels: tensor([0, 3, 1, 8])
# Labels: tensor([1, 3, 5, 5])
# Labels: tensor([2, 1, 5, 1])
# Labels: tensor([4, 5, 0, 0])
# Labels: tensor([8, 3, 0, 1])
# Labels: tensor([0, 9, 1, 5])
# Labels: tensor([7, 7, 1, 2])
# Labels: tensor([1, 7, 7, 4])
# Labels: tensor([3, 4, 5, 5])
# Labels: tensor([9, 9, 8, 6])
# Labels: tensor([0, 9, 1, 7])
# Labels: tensor([8, 8, 7, 0])
# Labels: tensor([1, 3, 4, 5])
# Labels: tensor([8, 4, 4, 5])
# Labels: tensor([1, 9, 5, 7])
# Labels: tensor([3, 1, 2, 8])
# Labels: tensor([9, 2, 9, 3])
# Labels: tensor([2, 3, 4, 6])
# Labels: tensor([1, 7, 2, 4])
# Labels: tensor([5, 9, 5, 2])
# Labels: tensor([3, 1, 5, 1])
# Labels: tensor([9, 1, 9, 9])
# Labels: tensor([5, 8, 9, 4])
# Labels: tensor([1, 4, 1, 5])
# Labels: tensor([2, 9, 1, 1])
# Labels: tensor([6, 4, 4, 9])
# Labels: tensor([7, 1, 0, 4])
# Labels: tensor([2, 7, 1, 1])
# Labels: tensor([5, 3, 6, 6])
# Labels: tensor([5, 0, 5, 6])
# Labels: tensor([3, 2, 4, 7])
# Labels: tensor([0, 7, 2, 2])
# Labels: tensor([1, 4, 1, 8])
# Labels: tensor([6, 1, 3, 8])
# Labels: tensor([2, 4, 3, 3])
# Labels: tensor([3, 0, 8, 4])
# Labels: tensor([7, 0, 3, 1])
# Labels: tensor([8, 1, 1, 9])
# Labels: tensor([4, 5, 3, 3])
# Labels: tensor([8, 2, 0, 8])
# Labels: tensor([2, 3, 1, 2])
# Labels: tensor([7, 2, 6, 2])
# Labels: tensor([5, 4, 8, 8])
# Labels: tensor([2, 1, 7, 2])
# Labels: tensor([7, 7, 5, 8])
# Labels: tensor([6, 8, 0, 4])
# Labels: tensor([1, 4, 4, 7])
# Labels: tensor([8, 6, 9, 3])
# Labels: tensor([0, 6, 2, 8])
# Labels: tensor([0, 5, 2, 4])
# Labels: tensor([7, 9, 6, 3])
# Labels: tensor([4, 1, 2, 3])
# Labels: tensor([6, 5, 2, 3])
# Labels: tensor([7, 3, 2, 3])
# Labels: tensor([5, 2, 0, 9])
# Labels: tensor([7, 0, 6, 5])
# Labels: tensor([7, 8, 5, 7])
# Labels: tensor([3, 2, 5, 6])
# Labels: tensor([4, 3, 8, 1])
# Labels: tensor([3, 5, 6, 6])
# Labels: tensor([0, 2, 4, 9])
# Labels: tensor([3, 8, 5, 8])
# Labels: tensor([2, 6, 5, 3])
# Labels: tensor([9, 2, 9, 2])
# Labels: tensor([9, 6, 5, 7])
# Labels: tensor([5, 4, 4, 0])
# Labels: tensor([7, 7, 8, 3])
# Labels: tensor([6, 6, 2, 7])
# Labels: tensor([5, 3, 8, 9])
# Labels: tensor([4, 8, 9, 6])
# Labels: tensor([6, 5, 1, 5])
# Labels: tensor([6, 6, 4, 7])
# Labels: tensor([1, 2, 6, 9])
# Labels: tensor([6, 5, 2, 3])
# Labels: tensor([6, 5, 9, 0])
# Labels: tensor([3, 8, 5, 7])
# Labels: tensor([8, 6, 5, 9])
# Labels: tensor([5, 1, 1, 8])
# Labels: tensor([7, 2, 3, 4])
# Labels: tensor([6, 4, 5, 8])
# Labels: tensor([1, 7, 2, 3])
# Labels: tensor([7, 5, 2, 6])
# Labels: tensor([5, 2, 8, 4])
# Labels: tensor([0, 3, 1, 3])
# Labels: tensor([3, 3, 6, 9])
# Labels: tensor([5, 7, 0, 8])
# Labels: tensor([5, 2, 5, 6])
# Labels: tensor([2, 3, 2, 5])
# Labels: tensor([6, 8, 2, 5])
# Labels: tensor([2, 3, 0, 3])
# Labels: tensor([7, 4, 5, 2])
# Labels: tensor([7, 3, 0, 1])
# Labels: tensor([2, 6, 9, 1])
# Labels: tensor([2, 0, 9, 2])
# Labels: tensor([0, 9, 3, 9])
# Labels: tensor([3, 9, 9, 1])
# Labels: tensor([3, 0, 5, 6])
# Labels: tensor([5, 7, 1, 6])
# Labels: tensor([7, 5, 8, 6])
# Labels: tensor([9, 9, 1, 4])
# Labels: tensor([7, 5, 9, 2])
# Labels: tensor([0, 6, 7, 6])
# Labels: tensor([6, 9, 5, 0])
# Labels: tensor([0, 4, 7, 6])
# Labels: tensor([4, 8, 8, 5])
# Labels: tensor([8, 0, 6, 7])
# Labels: tensor([6, 7, 3, 0])
# Labels: tensor([2, 9, 9, 9])
# Labels: tensor([3, 3, 5, 0])
# Labels: tensor([8, 5, 9, 9])
# Labels: tensor([1, 6, 5, 2])
# Labels: tensor([2, 3, 1, 3])
# Labels: tensor([5, 0, 8, 1])
# Labels: tensor([9, 9, 5, 7])
# Labels: tensor([6, 7, 2, 9])
# Labels: tensor([4, 4, 4, 6])
# Labels: tensor([7, 8, 7, 4])
# Labels: tensor([8, 1, 2, 8])
# Labels: tensor([3, 8, 4, 4])
# Labels: tensor([6, 1, 7, 2])
# Labels: tensor([3, 1, 0, 7])
# Labels: tensor([7, 7, 5, 2])
# Labels: tensor([4, 1, 5, 2])
# Labels: tensor([5, 7, 7, 6])
# Labels: tensor([7, 5, 8, 8])
# Labels: tensor([7, 6, 9, 3])
# Labels: tensor([0, 5, 9, 8])
# Labels: tensor([9, 7, 6, 9])
# Labels: tensor([5, 2, 8, 1])
# Labels: tensor([6, 4, 3, 2])
# Labels: tensor([1, 0, 3, 8])
# Labels: tensor([1, 7, 0, 6])
# Labels: tensor([3, 6, 3, 0])
# Labels: tensor([5, 7, 8, 2])
# Labels: tensor([5, 4, 0, 0])
# Labels: tensor([3, 6, 2, 6])
# Labels: tensor([0, 9, 5, 4])
# Labels: tensor([0, 9, 2, 7])
# Labels: tensor([0, 0, 5, 9])
# Labels: tensor([7, 5, 2, 2])
# Labels: tensor([2, 2, 7, 0])
# Labels: tensor([1, 8, 3, 1])
# Labels: tensor([8, 4, 0, 0])
# Labels: tensor([1, 8, 7, 1])
# Labels: tensor([7, 0, 2, 6])
# Labels: tensor([7, 0, 3, 1])
# Labels: tensor([6, 6, 7, 6])
# Labels: tensor([4, 7, 5, 6])
# Labels: tensor([6, 3, 3, 7])
# Labels: tensor([5, 5, 4, 1])
# Labels: tensor([5, 3, 9, 8])
# Labels: tensor([9, 9, 4, 2])
# Labels: tensor([8, 0, 2, 0])
# Labels: tensor([0, 7, 1, 5])
# Labels: tensor([0, 7, 4, 7])
# Labels: tensor([8, 7, 6, 7])
# Labels: tensor([3, 0, 1, 5])
# Labels: tensor([9, 6, 2, 5])
# Labels: tensor([2, 7, 4, 5])
# Labels: tensor([0, 3, 6, 9])
# Labels: tensor([5, 9, 8, 2])
# Labels: tensor([2, 7, 2, 7])
# Labels: tensor([8, 1, 3, 1])
# Labels: tensor([5, 9, 6, 9])
# Labels: tensor([4, 4, 4, 9])
# Labels: tensor([7, 4, 1, 8])
# Labels: tensor([4, 7, 6, 5])
# Labels: tensor([7, 1, 9, 8])
# Labels: tensor([6, 7, 2, 1])
# Labels: tensor([0, 7, 9, 6])
# Labels: tensor([9, 8, 6, 8])
# Labels: tensor([4, 0, 5, 7])
# Labels: tensor([3, 2, 6, 9])
# Labels: tensor([0, 1, 8, 5])
# Labels: tensor([8, 8, 5, 6])
# Labels: tensor([2, 8, 7, 0])
# Labels: tensor([6, 2, 0, 3])
# Labels: tensor([7, 6, 2, 6])
# Labels: tensor([8, 1, 7, 9])
# Labels: tensor([9, 9, 6, 5])
# Labels: tensor([7, 3, 0, 8])
# Labels: tensor([2, 5, 3, 7])
# Labels: tensor([4, 8, 3, 9])
# Labels: tensor([4, 9, 0, 5])
# Labels: tensor([2, 3, 8, 5])
# Labels: tensor([1, 6, 9, 6])
# Labels: tensor([9, 3, 5, 3])
# Labels: tensor([1, 0, 5, 8])
# Labels: tensor([9, 7, 6, 0])
# Labels: tensor([6, 9, 9, 0])
# Labels: tensor([4, 6, 1, 5])
# Labels: tensor([2, 9, 2, 3])
# Labels: tensor([7, 6, 3, 5])
# Labels: tensor([3, 2, 2, 2])
# Labels: tensor([7, 5, 8, 2])
# Labels: tensor([8, 7, 3, 8])
# Labels: tensor([1, 6, 0, 5])
# Labels: tensor([4, 5, 5, 6])
# Labels: tensor([7, 2, 3, 8])
# Labels: tensor([9, 0, 2, 8])
# Labels: tensor([5, 4, 2, 5])
# Labels: tensor([9, 4, 2, 8])
# Labels: tensor([7, 0, 2, 4])
# Labels: tensor([5, 4, 1, 7])
# Labels: tensor([6, 7, 6, 7])
# Labels: tensor([1, 2, 1, 8])
# Labels: tensor([2, 6, 6, 5])
# Labels: tensor([6, 9, 8, 7])
# Labels: tensor([5, 1, 0, 8])
# Labels: tensor([1, 2, 0, 0])
# Labels: tensor([7, 4, 1, 1])
# Labels: tensor([5, 4, 4, 5])
# Labels: tensor([6, 8, 1, 3])
# Labels: tensor([2, 9, 1, 8])
# Labels: tensor([9, 4, 5, 6])
# Labels: tensor([9, 3, 0, 5])
# Labels: tensor([9, 8, 5, 5])
# Labels: tensor([4, 4, 4, 1])
# Labels: tensor([6, 2, 5, 2])
# Labels: tensor([1, 6, 2, 2])
# Labels: tensor([9, 8, 6, 6])
# Labels: tensor([0, 9, 6, 0])
# Labels: tensor([1, 6, 1, 3])
# Labels: tensor([1, 1, 0, 9])
# Labels: tensor([2, 3, 5, 6])
# Labels: tensor([7, 5, 6, 1])
# Labels: tensor([2, 6, 7, 3])
# Labels: tensor([7, 9, 6, 1])
# Labels: tensor([6, 1, 7, 4])
# Labels: tensor([6, 4, 1, 8])
# Labels: tensor([2, 4, 9, 2])
# Labels: tensor([9, 8, 6, 9])
# Labels: tensor([3, 3, 2, 7])
# Labels: tensor([5, 0, 1, 8])
# Labels: tensor([8, 7, 9, 2])
# Labels: tensor([1, 6, 1, 5])
# Labels: tensor([6, 5, 9, 2])
# Labels: tensor([6, 5, 5, 9])
# Labels: tensor([8, 8, 0, 0])
# Labels: tensor([2, 0, 4, 1])
# Labels: tensor([1, 1, 5, 5])
# Labels: tensor([0, 6, 5, 1])
# Labels: tensor([1, 0, 0, 6])
# Labels: tensor([6, 9, 3, 2])
# Labels: tensor([4, 7, 8, 2])
# Labels: tensor([0, 5, 5, 0])
# Labels: tensor([0, 8, 4, 8])
# Labels: tensor([9, 7, 0, 1])
# Labels: tensor([9, 4, 1, 2])
# Labels: tensor([4, 6, 5, 4])
# Labels: tensor([6, 5, 8, 2])
# Labels: tensor([2, 4, 8, 7])
# Labels: tensor([1, 5, 7, 6])
# Labels: tensor([1, 8, 0, 2])
# Labels: tensor([3, 0, 9, 8])
# Labels: tensor([8, 2, 0, 8])
# Labels: tensor([8, 1, 6, 1])
# Labels: tensor([7, 4, 6, 5])
# Labels: tensor([2, 7, 4, 9])
# Labels: tensor([5, 6, 6, 8])
# Labels: tensor([1, 5, 6, 8])
# Labels: tensor([5, 6, 0, 1])
# Labels: tensor([9, 9, 3, 2])
# Labels: tensor([2, 0, 8, 9])
# Labels: tensor([6, 8, 9, 6])
# Labels: tensor([6, 5, 4, 3])
# Labels: tensor([0, 0, 9, 3])
# Labels: tensor([5, 1, 7, 4])
# Labels: tensor([1, 0, 9, 3])
# Labels: tensor([0, 7, 9, 6])
# Labels: tensor([7, 0, 9, 1])
# Labels: tensor([6, 6, 5, 7])
# Labels: tensor([1, 3, 7, 2])
# Labels: tensor([1, 4, 6, 0])
# Labels: tensor([4, 2, 5, 5])
# Labels: tensor([1, 0, 3, 3])
# Labels: tensor([8, 9, 3, 5])
# Labels: tensor([6, 0, 9, 9])
# Labels: tensor([0, 6, 3, 5])
# Labels: tensor([1, 4, 9, 7])
# Labels: tensor([8, 9, 8, 2])
# Labels: tensor([2, 3, 4, 2])
# Labels: tensor([4, 4, 3, 6])
# Labels: tensor([7, 1, 2, 5])
# Labels: tensor([1, 1, 6, 3])
# Labels: tensor([5, 2, 1, 2])
# Labels: tensor([3, 7, 7, 1])
# Labels: tensor([8, 8, 6, 5])
# Labels: tensor([9, 2, 3, 0])
# Labels: tensor([2, 2, 7, 2])
# Labels: tensor([8, 5, 4, 8])
# Labels: tensor([5, 7, 0, 2])
# Labels: tensor([6, 2, 4, 7])
# Labels: tensor([5, 3, 2, 2])
# Labels: tensor([4, 9, 1, 9])
# Labels: tensor([4, 0, 3, 3])
# Labels: tensor([2, 8, 9, 0])
# Labels: tensor([7, 5, 6, 7])
# Labels: tensor([0, 1, 4, 6])
# Labels: tensor([9, 7, 3, 5])
# Labels: tensor([1, 7, 8, 3])
# Labels: tensor([9, 0, 4, 7])
# Labels: tensor([3, 8, 8, 7])
# Labels: tensor([4, 6, 6, 7])
# Labels: tensor([2, 6, 5, 5])
# Labels: tensor([3, 2, 9, 8])
# Labels: tensor([5, 3, 3, 9])
# Labels: tensor([3, 9, 9, 5])
# Labels: tensor([6, 4, 4, 3])
# Labels: tensor([2, 9, 5, 0])
# Labels: tensor([3, 9, 4, 1])
# Labels: tensor([8, 8, 3, 3])
# Labels: tensor([0, 2, 6, 9])
# Labels: tensor([2, 9, 9, 2])
# Labels: tensor([0, 3, 1, 9])
# Labels: tensor([2, 9, 4, 1])
# Labels: tensor([4, 6, 7, 0])
# Labels: tensor([7, 7, 3, 1])
# Labels: tensor([8, 5, 1, 3])
# Labels: tensor([4, 8, 8, 6])
# Labels: tensor([0, 4, 5, 4])
# Labels: tensor([7, 6, 8, 9])
# Labels: tensor([1, 2, 9, 9])
# Labels: tensor([0, 5, 3, 0])
# Labels: tensor([7, 6, 7, 6])
# Labels: tensor([0, 1, 5, 9])
# Labels: tensor([6, 5, 9, 4])
# Labels: tensor([6, 8, 3, 0])
# Labels: tensor([1, 0, 6, 6])
# Labels: tensor([9, 0, 5, 7])
# Labels: tensor([7, 3, 3, 4])
# Labels: tensor([8, 1, 7, 1])
# Labels: tensor([6, 6, 8, 9])
# Labels: tensor([2, 5, 1, 4])
# Labels: tensor([8, 8, 0, 1])
# Labels: tensor([9, 9, 3, 2])
# Labels: tensor([0, 7, 5, 2])
# Labels: tensor([8, 2, 3, 3])
# Labels: tensor([4, 0, 0, 0])
# Labels: tensor([9, 6, 6, 6])
# Labels: tensor([5, 5, 6, 6])
# Labels: tensor([3, 4, 1, 8])
# Labels: tensor([3, 1, 4, 9])
# Labels: tensor([0, 3, 8, 3])
# Labels: tensor([4, 7, 5, 2])
# Labels: tensor([3, 3, 0, 6])
# Labels: tensor([4, 0, 8, 5])
# Labels: tensor([4, 9, 4, 7])
# Labels: tensor([4, 4, 7, 9])
# Labels: tensor([6, 2, 8, 8])
# Labels: tensor([4, 1, 2, 5])
# Labels: tensor([6, 4, 1, 7])
# Labels: tensor([4, 8, 0, 6])
# Labels: tensor([5, 5, 5, 8])
# Labels: tensor([7, 9, 3, 7])
# Labels: tensor([3, 4, 2, 2])
# Labels: tensor([8, 1, 5, 5])
# Labels: tensor([9, 1, 0, 3])
# Labels: tensor([3, 6, 9, 0])
# Labels: tensor([6, 4, 3, 7])
# Labels: tensor([2, 6, 7, 3])
# Labels: tensor([2, 8, 6, 3])
# Labels: tensor([3, 7, 6, 1])
# Labels: tensor([1, 3, 5, 4])
# Labels: tensor([5, 1, 1, 9])
# Labels: tensor([5, 8, 4, 7])
# Labels: tensor([5, 2, 2, 1])
# Labels: tensor([0, 4, 2, 0])
# Labels: tensor([4, 6, 8, 6])
# Labels: tensor([9, 4, 9, 5])
# Labels: tensor([5, 0, 9, 9])
# Labels: tensor([3, 0, 2, 6])
# Labels: tensor([0, 8, 7, 7])
# Labels: tensor([7, 6, 1, 3])
# Labels: tensor([9, 8, 6, 2])
# Labels: tensor([0, 8, 0, 4])
# Labels: tensor([6, 5, 5, 6])
# Labels: tensor([9, 8, 9, 9])
# Labels: tensor([8, 3, 7, 3])
# Labels: tensor([2, 1, 9, 8])
# Labels: tensor([0, 8, 8, 4])
# Labels: tensor([9, 8, 2, 5])
# Labels: tensor([9, 8, 2, 9])
# Labels: tensor([7, 5, 5, 2])
# Labels: tensor([8, 1, 3, 5])
# Labels: tensor([2, 8, 7, 7])
# Labels: tensor([8, 0, 5, 5])
# Labels: tensor([8, 9, 1, 4])
# Labels: tensor([1, 0, 1, 5])
# Labels: tensor([5, 8, 8, 7])
# Labels: tensor([3, 2, 8, 3])
# Labels: tensor([8, 6, 7, 7])
# Labels: tensor([7, 8, 9, 2])
# Labels: tensor([1, 8, 8, 1])
# Labels: tensor([2, 5, 2, 7])
# Labels: tensor([1, 3, 1, 6])
# Labels: tensor([1, 2, 4, 3])
# Labels: tensor([8, 5, 4, 6])
# Labels: tensor([4, 8, 9, 8])
# Labels: tensor([6, 2, 4, 1])
# Labels: tensor([3, 7, 1, 2])
# Labels: tensor([4, 2, 5, 0])
# Labels: tensor([0, 8, 6, 7])
# Labels: tensor([6, 0, 7, 2])
# Labels: tensor([7, 5, 5, 6])
# Labels: tensor([3, 3, 0, 8])
# Labels: tensor([2, 2, 9, 5])
# Labels: tensor([2, 7, 6, 0])
# Labels: tensor([3, 9, 4, 2])
# ...
# Labels: tensor([8, 3, 7, 3])
# Labels: tensor([5, 8, 4, 8])
# Labels: tensor([8, 2, 7, 1])
# Labels: tensor([9, 0, 0, 5])
# Labels: tensor([3, 5, 7, 5])
# Labels: tensor([8, 9, 6, 8])
# Labels: tensor([7, 9, 2, 9])
# Labels: tensor([1, 9, 9, 8])
# Labels: tensor([6, 6, 2, 1])
# Labels: tensor([8, 1, 7, 7])
# Labels: tensor([7, 0, 7, 5])
# Labels: tensor([5, 0, 8, 5])
# Labels: tensor([2, 8, 6, 0])
# Labels: tensor([5, 3, 5, 9])
# Labels: tensor([6, 7, 7, 4])
# Labels: tensor([2, 9, 4, 5])
# Labels: tensor([6, 4, 0, 5])
# Labels: tensor([8, 0, 6, 9])
# Labels: tensor([7, 8, 9, 2])
# Labels: tensor([8, 2, 1, 0])
# Labels: tensor([8, 4, 3, 6])
# Labels: tensor([8, 0, 1, 9])
# Labels: tensor([4, 1, 3, 7])
# Labels: tensor([4, 8, 4, 3])
# Labels: tensor([6, 4, 1, 0])
# Labels: tensor([7, 8, 7, 9])
# Labels: tensor([1, 1, 0, 4])
# Labels: tensor([2, 4, 6, 1])
# Labels: tensor([9, 0, 9, 4])
# Labels: tensor([9, 6, 8, 0])
# Labels: tensor([3, 6, 3, 2])
# Labels: tensor([2, 9, 5, 5])
# Labels: tensor([6, 3, 3, 0])
# Labels: tensor([0, 3, 6, 5])
# Labels: tensor([2, 3, 4, 7])
# Labels: tensor([8, 9, 4, 3])
# Labels: tensor([1, 7, 1, 2])
# Labels: tensor([1, 1, 4, 0])
# Labels: tensor([2, 9, 8, 3])
# Labels: tensor([6, 0, 4, 3])
# Labels: tensor([8, 8, 5, 8])
# Labels: tensor([6, 1, 7, 9])
# Labels: tensor([8, 9, 3, 5])
# Labels: tensor([7, 2, 3, 5])
# Labels: tensor([0, 1, 6, 8])
# Labels: tensor([3, 9, 6, 6])
# Labels: tensor([2, 9, 1, 2])
# Labels: tensor([7, 8, 9, 1])
# Labels: tensor([5, 9, 7, 4])
# Labels: tensor([4, 0, 1, 8])
# Labels: tensor([9, 4, 9, 4])
# Labels: tensor([2, 3, 7, 6])
# Labels: tensor([5, 0, 7, 5])
# Labels: tensor([2, 9, 8, 4])
# Labels: tensor([7, 9, 3, 7])
# Labels: tensor([5, 2, 6, 7])
# Labels: tensor([9, 1, 8, 4])
# Labels: tensor([8, 1, 7, 6])
# Labels: tensor([5, 4, 6, 5])
# Labels: tensor([6, 1, 8, 0])
# Labels: tensor([3, 0, 5, 6])
# Labels: tensor([2, 6, 6, 4])
# Labels: tensor([1, 3, 5, 0])
# Labels: tensor([1, 9, 4, 3])
# Labels: tensor([8, 1, 4, 7])
# Labels: tensor([9, 8, 8, 9])
# Labels: tensor([5, 9, 6, 7])
# Labels: tensor([3, 2, 3, 7])
# Labels: tensor([5, 4, 2, 3])
# Labels: tensor([6, 8, 8, 4])
# Labels: tensor([1, 6, 4, 6])
# Labels: tensor([9, 6, 1, 9])
# Labels: tensor([9, 4, 9, 7])
# Labels: tensor([4, 1, 7, 7])
# Labels: tensor([6, 6, 0, 4])
# Labels: tensor([3, 4, 2, 8])
# Labels: tensor([0, 9, 4, 5])
# Labels: tensor([2, 3, 8, 4])
# Labels: tensor([0, 1, 5, 6])
# Labels: tensor([0, 8, 3, 2])
# Labels: tensor([6, 1, 8, 1])
# Labels: tensor([4, 8, 9, 5])
# Labels: tensor([8, 5, 6, 5])
# Labels: tensor([6, 8, 9, 6])
# Labels: tensor([5, 6, 9, 1])
# Labels: tensor([2, 2, 9, 6])
# Labels: tensor([4, 8, 4, 0])
# Labels: tensor([5, 7, 9, 5])
# Labels: tensor([2, 9, 6, 8])
# Labels: tensor([5, 6, 1, 4])
# Labels: tensor([0, 7, 5, 5])
# Labels: tensor([8, 1, 0, 7])
# Labels: tensor([2, 4, 5, 6])
# Labels: tensor([2, 4, 3, 9])
# Labels: tensor([1, 9, 8, 3])
# Labels: tensor([4, 3, 0, 3])
# Labels: tensor([7, 5, 2, 3])
# Labels: tensor([6, 8, 0, 1])
# Labels: tensor([9, 5, 3, 7])
# Labels: tensor([2, 7, 0, 9])
# Labels: tensor([8, 5, 2, 3])
# Labels: tensor([9, 6, 2, 6])
# Labels: tensor([4, 6, 8, 1])
# Labels: tensor([3, 2, 1, 6])
# Labels: tensor([6, 7, 8, 3])
# Labels: tensor([0, 9, 1, 5])
# Labels: tensor([5, 1, 4, 2])
# Labels: tensor([8, 9, 9, 7])
# Labels: tensor([4, 2, 7, 6])
# Labels: tensor([0, 0, 1, 2])
# Labels: tensor([1, 2, 5, 9])
# Labels: tensor([3, 4, 7, 2])
# Labels: tensor([5, 4, 5, 6])
# Labels: tensor([1, 1, 8, 4])
# Labels: tensor([1, 3, 2, 5])
# Labels: tensor([7, 9, 5, 1])
# Labels: tensor([5, 2, 1, 4])
# Labels: tensor([9, 2, 8, 4])
# Labels: tensor([2, 8, 3, 9])
# Labels: tensor([8, 5, 1, 0])
# Labels: tensor([0, 4, 8, 5])
# Labels: tensor([1, 8, 9, 3])
# Labels: tensor([2, 7, 4, 6])
# Labels: tensor([3, 4, 4, 2])
# Labels: tensor([8, 2, 9, 6])
# Labels: tensor([9, 2, 0, 2])
# Labels: tensor([9, 9, 8, 2])
# Labels: tensor([2, 9, 6, 0])
# Labels: tensor([0, 5, 7, 9])
# Labels: tensor([6, 4, 1, 1])
# Labels: tensor([7, 1, 0, 7])
# Labels: tensor([1, 2, 0, 9])
# Labels: tensor([1, 7, 7, 6])
# Labels: tensor([7, 2, 1, 0])
# Labels: tensor([1, 7, 9, 2])
# Labels: tensor([6, 6, 7, 8])
# Labels: tensor([4, 9, 7, 9])
# Labels: tensor([9, 3, 8, 7])
# Labels: tensor([3, 7, 5, 4])
# Labels: tensor([3, 5, 1, 8])
# Labels: tensor([7, 5, 5, 1])
# Labels: tensor([5, 9, 9, 8])
# Labels: tensor([9, 6, 3, 8])
# Labels: tensor([5, 0, 4, 4])
# Labels: tensor([1, 1, 9, 1])
# Labels: tensor([3, 3, 1, 1])
# Labels: tensor([9, 0, 7, 2])
# Labels: tensor([7, 4, 5, 0])
# Labels: tensor([2, 4, 6, 8])
# Labels: tensor([7, 6, 6, 7])
# Labels: tensor([5, 2, 3, 6])
# Labels: tensor([7, 9, 4, 8])
# Labels: tensor([1, 3, 5, 3])
# Labels: tensor([0, 8, 8, 8])
# Labels: tensor([7, 5, 4, 5])
# Labels: tensor([0, 3, 7, 1])
# Labels: tensor([7, 1, 0, 3])
# Labels: tensor([2, 3, 6, 6])
# Labels: tensor([5, 6, 0, 4])
# Labels: tensor([2, 2, 6, 5])
# Labels: tensor([8, 6, 2, 9])
# Labels: tensor([9, 4, 6, 9])
# Labels: tensor([1, 5, 5, 2])
# Labels: tensor([2, 3, 6, 2])
# Labels: tensor([6, 4, 1, 5])
# Labels: tensor([4, 5, 8, 9])
# Labels: tensor([2, 9, 7, 9])
# Labels: tensor([3, 1, 5, 5])
# Labels: tensor([1, 6, 9, 3])
# Labels: tensor([7, 9, 2, 6])
# Labels: tensor([2, 7, 4, 0])
# Labels: tensor([6, 6, 1, 5])
# Labels: tensor([4, 2, 5, 2])
# Labels: tensor([9, 8, 6, 0])
# Labels: tensor([0, 1, 4, 6])
# Labels: tensor([0, 7, 9, 3])
# Labels: tensor([3, 1, 1, 3])
# Labels: tensor([7, 9, 3, 8])
# Labels: tensor([9, 6, 2, 4])
# Labels: tensor([5, 3, 5, 4])
# Labels: tensor([8, 1, 2, 5])
# Labels: tensor([4, 9, 0, 2])
# Labels: tensor([4, 6, 6, 7])
# Labels: tensor([9, 6, 7, 0])
# Labels: tensor([9, 1, 0, 6])
# Labels: tensor([5, 1, 0, 6])
# Labels: tensor([2, 4, 1, 0])
# Labels: tensor([3, 4, 3, 1])
# Labels: tensor([5, 4, 0, 7])
# Labels: tensor([9, 1, 4, 0])
# Labels: tensor([2, 6, 7, 1])
# Labels: tensor([7, 6, 9, 1])
# Labels: tensor([0, 2, 4, 9])
# Labels: tensor([4, 6, 5, 0])
# Labels: tensor([3, 2, 4, 3])
# Labels: tensor([3, 3, 2, 5])
# Labels: tensor([9, 2, 5, 5])
# Labels: tensor([2, 0, 3, 4])
# Labels: tensor([1, 6, 7, 7])
# Labels: tensor([5, 4, 4, 4])
# Labels: tensor([3, 8, 8, 6])
# Labels: tensor([4, 4, 6, 8])
# Labels: tensor([5, 7, 0, 6])
# Labels: tensor([3, 4, 8, 1])
# Labels: tensor([9, 6, 9, 0])
# Labels: tensor([9, 7, 8, 2])
# Labels: tensor([6, 4, 2, 8])
# Labels: tensor([8, 4, 5, 8])
# Labels: tensor([4, 5, 5, 1])
# Labels: tensor([4, 1, 4, 5])
# Labels: tensor([0, 9, 1, 8])
# Labels: tensor([7, 9, 0, 1])
# Labels: tensor([7, 7, 0, 3])
# Labels: tensor([9, 5, 8, 2])
# Labels: tensor([4, 8, 4, 8])
# Labels: tensor([6, 5, 7, 3])
# Labels: tensor([2, 9, 6, 4])
# Labels: tensor([7, 3, 8, 0])
# Labels: tensor([2, 5, 2, 1])
# Labels: tensor([8, 4, 7, 4])
# Labels: tensor([2, 0, 9, 0])
# Labels: tensor([2, 0, 2, 9])
# Labels: tensor([7, 1, 8, 7])
# Labels: tensor([8, 0, 2, 8])
# Labels: tensor([7, 6, 2, 2])
# Labels: tensor([2, 9, 7, 5])
# Labels: tensor([1, 3, 5, 6])
# Labels: tensor([9, 1, 5, 3])
# Labels: tensor([9, 8, 7, 0])
# Labels: tensor([2, 9, 9, 0])
# Labels: tensor([4, 9, 7, 0])
# Labels: tensor([3, 3, 1, 4])
# Labels: tensor([5, 0, 3, 1])
# Labels: tensor([9, 3, 4, 0])
# Labels: tensor([1, 2, 3, 7])
# Labels: tensor([8, 2, 3, 6])
# Labels: tensor([1, 6, 1, 5])
# Labels: tensor([7, 5, 0, 7])
# Labels: tensor([9, 5, 3, 9])
# Labels: tensor([3, 0, 8, 5])
# Labels: tensor([8, 0, 5, 3])
# Labels: tensor([8, 0, 2, 1])
# Labels: tensor([4, 8, 2, 5])
# Labels: tensor([3, 9, 2, 3])
# Labels: tensor([9, 5, 0, 7])
# Labels: tensor([8, 1, 8, 9])
# Labels: tensor([1, 3, 2, 4])
# Labels: tensor([0, 6, 2, 8])
# Labels: tensor([4, 6, 8, 4])
# Labels: tensor([1, 7, 0, 1])
# Labels: tensor([8, 0, 6, 9])
# Labels: tensor([4, 8, 0, 7])
# Labels: tensor([6, 9, 7, 4])
# Labels: tensor([9, 3, 8, 5])
# Labels: tensor([5, 7, 6, 9])
# Labels: tensor([6, 4, 3, 4])
# Labels: tensor([0, 6, 0, 7])
# Labels: tensor([0, 1, 0, 1])
# Labels: tensor([4, 2, 0, 5])
# Labels: tensor([0, 3, 9, 5])
# Labels: tensor([5, 1, 5, 7])
# Labels: tensor([5, 9, 4, 2])
# Labels: tensor([6, 9, 2, 6])
# Labels: tensor([5, 8, 8, 1])
# Labels: tensor([5, 2, 2, 6])
# Labels: tensor([9, 8, 4, 2])
# Labels: tensor([1, 5, 6, 0])
# Labels: tensor([5, 2, 6, 6])
# Labels: tensor([1, 2, 3, 9])
# Labels: tensor([5, 0, 6, 7])
# Labels: tensor([7, 1, 9, 0])
# Labels: tensor([7, 0, 2, 2])
# Labels: tensor([5, 6, 2, 9])
# Labels: tensor([6, 4, 6, 9])
# Labels: tensor([2, 6, 7, 3])
# Labels: tensor([4, 7, 5, 4])
# Labels: tensor([0, 2, 6, 8])
# Labels: tensor([1, 9, 7, 4])
# Labels: tensor([7, 2, 1, 1])
# Labels: tensor([5, 7, 5, 2])
# Labels: tensor([3, 6, 5, 3])
# Labels: tensor([2, 5, 8, 2])
# Labels: tensor([6, 1, 2, 4])
# Labels: tensor([6, 6, 6, 6])
# Labels: tensor([9, 2, 6, 0])
# Labels: tensor([8, 6, 8, 1])
# Labels: tensor([0, 3, 2, 2])
# Labels: tensor([3, 1, 3, 3])
# Labels: tensor([6, 8, 7, 5])
# Labels: tensor([4, 1, 1, 8])
# Labels: tensor([8, 3, 0, 2])
# Labels: tensor([5, 2, 7, 3])
# Labels: tensor([8, 7, 2, 0])
# Labels: tensor([3, 3, 5, 4])
# Labels: tensor([9, 3, 5, 3])
# Labels: tensor([3, 0, 5, 3])
# Labels: tensor([2, 9, 8, 8])
# Labels: tensor([3, 4, 8, 1])
# Labels: tensor([9, 2, 6, 8])
# Labels: tensor([6, 3, 0, 0])
# Labels: tensor([4, 4, 5, 2])
# Labels: tensor([7, 5, 4, 0])
# Labels: tensor([7, 5, 8, 6])
# Labels: tensor([3, 2, 7, 0])
# Labels: tensor([5, 7, 2, 5])
# Labels: tensor([6, 2, 6, 3])
# Labels: tensor([9, 2, 0, 4])
# Labels: tensor([5, 0, 8, 5])
# Labels: tensor([9, 0, 4, 7])
# Labels: tensor([1, 1, 9, 9])
# Labels: tensor([7, 3, 6, 2])
# Labels: tensor([5, 8, 3, 3])
# Labels: tensor([5, 8, 9, 8])
# Labels: tensor([4, 1, 3, 2])
# Labels: tensor([1, 8, 1, 1])
# Labels: tensor([2, 1, 1, 6])
# Labels: tensor([5, 2, 6, 4])
# Labels: tensor([1, 8, 4, 6])
# Labels: tensor([3, 7, 9, 2])
# Labels: tensor([3, 7, 2, 3])
# Labels: tensor([2, 0, 9, 4])
# Labels: tensor([9, 5, 5, 9])
# Labels: tensor([0, 3, 1, 5])
# Labels: tensor([4, 5, 8, 8])
# Labels: tensor([2, 7, 7, 2])
# Labels: tensor([9, 3, 5, 1])
# Labels: tensor([3, 3, 7, 7])
# Labels: tensor([0, 4, 1, 8])
# Labels: tensor([9, 0, 0, 2])
# Labels: tensor([7, 2, 1, 7])
# Labels: tensor([9, 1, 8, 9])
# Labels: tensor([3, 2, 1, 7])
# Labels: tensor([3, 8, 4, 6])
# Labels: tensor([8, 3, 7, 3])
# Labels: tensor([5, 8, 9, 2])
# Labels: tensor([1, 0, 6, 9])
# Labels: tensor([2, 0, 6, 0])
# Labels: tensor([9, 9, 2, 6])
# Labels: tensor([3, 4, 6, 9])
# Labels: tensor([6, 6, 5, 9])
# Labels: tensor([3, 4, 1, 1])
# Labels: tensor([8, 0, 6, 2])
# Labels: tensor([6, 8, 5, 6])
# Labels: tensor([0, 7, 5, 7])
# Labels: tensor([1, 1, 2, 6])
# Labels: tensor([9, 6, 0, 0])
# Labels: tensor([9, 6, 1, 6])
# Labels: tensor([8, 0, 5, 3])
# Labels: tensor([8, 1, 7, 0])
# Labels: tensor([2, 8, 6, 3])
# Labels: tensor([7, 3, 7, 5])
# Labels: tensor([9, 0, 7, 8])
# Labels: tensor([1, 5, 3, 6])
# Labels: tensor([5, 1, 2, 0])
# Labels: tensor([6, 7, 9, 3])
# Labels: tensor([4, 2, 1, 0])
# Labels: tensor([6, 3, 0, 9])
# Labels: tensor([6, 0, 3, 3])
# Labels: tensor([4, 5, 7, 6])
# Labels: tensor([6, 9, 2, 7])
# Labels: tensor([1, 5, 7, 0])
# Labels: tensor([7, 9, 1, 0])
# Labels: tensor([2, 9, 5, 2])
# Labels: tensor([6, 5, 8, 5])
# Labels: tensor([6, 7, 1, 5])
# Labels: tensor([5, 4, 4, 9])
# Labels: tensor([5, 2, 7, 8])
# Labels: tensor([9, 8, 7, 3])
# Labels: tensor([9, 8, 7, 1])
# Labels: tensor([4, 2, 1, 9])
# Labels: tensor([5, 0, 3, 2])
# Labels: tensor([6, 1, 5, 4])
# Labels: tensor([7, 6, 3, 3])
# Labels: tensor([8, 9, 5, 6])
# Labels: tensor([8, 3, 3, 3])
# Labels: tensor([2, 8, 0, 9])
# Labels: tensor([9, 4, 6, 4])
# Labels: tensor([1, 9, 6, 5])
# Labels: tensor([5, 2, 2, 1])
# Labels: tensor([6, 0, 6, 9])
# Labels: tensor([0, 7, 4, 4])
# Labels: tensor([0, 6, 9, 5])
# Labels: tensor([6, 4, 6, 6])
# Labels: tensor([4, 1, 5, 7])
# Labels: tensor([0, 0, 7, 0])
# Labels: tensor([5, 5, 8, 2])
# Labels: tensor([4, 2, 1, 9])
# Labels: tensor([4, 6, 2, 8])
# Labels: tensor([9, 4, 1, 4])
# Labels: tensor([6, 7, 1, 2])
# Labels: tensor([6, 6, 7, 4])
# Labels: tensor([0, 5, 6, 7])
# Labels: tensor([1, 3, 9, 1])
# Labels: tensor([3, 9, 1, 6])
# Labels: tensor([6, 9, 0, 3])
# Labels: tensor([1, 9, 3, 8])
# Labels: tensor([7, 4, 2, 4])
# Labels: tensor([6, 5, 1, 8])
# Labels: tensor([3, 1, 1, 2])
# Labels: tensor([9, 8, 9, 6])
# Labels: tensor([0, 7, 8, 1])
# Labels: tensor([6, 3, 5, 6])
# Labels: tensor([1, 8, 5, 2])
# Labels: tensor([9, 7, 1, 8])
# Labels: tensor([1, 6, 4, 7])
# Labels: tensor([4, 8, 7, 8])
# Labels: tensor([4, 4, 9, 1])
# Labels: tensor([4, 3, 7, 4])
# Labels: tensor([6, 5, 0, 2])
# Labels: tensor([4, 2, 2, 7])
# Labels: tensor([7, 8, 0, 2])
# Labels: tensor([5, 2, 7, 5])
# Labels: tensor([9, 6, 3, 0])
# Labels: tensor([3, 3, 5, 6])
# Labels: tensor([3, 4, 3, 1])
# Labels: tensor([1, 5, 0, 6])
# Labels: tensor([3, 3, 5, 9])
# Labels: tensor([4, 9, 6, 2])
# Labels: tensor([6, 1, 8, 3])
# Labels: tensor([9, 1, 3, 2])
# Labels: tensor([7, 4, 4, 3])
# Labels: tensor([2, 7, 0, 8])
# Labels: tensor([2, 9, 0, 4])
# Labels: tensor([1, 3, 3, 9])
# Labels: tensor([6, 2, 3, 0])
# Labels: tensor([7, 6, 6, 8])
# Labels: tensor([9, 1, 3, 4])
# Labels: tensor([5, 2, 2, 3])
# Labels: tensor([3, 1, 1, 5])
# Labels: tensor([2, 9, 0, 1])
# Labels: tensor([3, 9, 6, 3])
# Labels: tensor([0, 3, 4, 4])
# Labels: tensor([2, 2, 7, 2])
# Labels: tensor([7, 8, 3, 3])
# Labels: tensor([2, 5, 6, 7])
# Labels: tensor([4, 9, 7, 2])
# Labels: tensor([7, 5, 4, 4])
# Labels: tensor([4, 9, 3, 5])
# Labels: tensor([7, 7, 9, 0])
# Labels: tensor([5, 3, 0, 8])
# Labels: tensor([0, 9, 1, 4])
# Labels: tensor([1, 9, 1, 5])
# Labels: tensor([3, 4, 3, 6])
# Labels: tensor([5, 8, 6, 0])
# Labels: tensor([1, 9, 2, 2])
# Labels: tensor([0, 7, 2, 7])
# Labels: tensor([2, 3, 4, 1])
# Labels: tensor([7, 9, 7, 1])
# Labels: tensor([3, 6, 3, 6])
# Labels: tensor([5, 0, 6, 9])
# Labels: tensor([8, 3, 0, 6])
# Labels: tensor([0, 4, 4, 8])
# Labels: tensor([1, 2, 5, 6])
# Labels: tensor([4, 2, 8, 3])
# Labels: tensor([6, 4, 8, 8])
# Labels: tensor([9, 3, 5, 6])
# Labels: tensor([8, 6, 6, 5])
# Labels: tensor([8, 2, 4, 2])
# Labels: tensor([7, 8, 9, 3])
# Labels: tensor([9, 1, 6, 1])
# Labels: tensor([1, 0, 7, 9])
# Labels: tensor([2, 7, 1, 5])
# Labels: tensor([3, 8, 4, 6])
# Labels: tensor([5, 9, 8, 9])
# Labels: tensor([4, 9, 7, 2])
# Labels: tensor([1, 8, 0, 9])
# Labels: tensor([0, 0, 7, 1])
# Labels: tensor([4, 6, 4, 4])
# Labels: tensor([1, 6, 1, 4])
# Labels: tensor([1, 0, 0, 7])
# Labels: tensor([4, 0, 2, 8])
# Labels: tensor([8, 9, 9, 5])
# Labels: tensor([3, 3, 0, 3])
# Labels: tensor([8, 6, 5, 0])
# Labels: tensor([6, 0, 3, 9])
# Labels: tensor([8, 7, 5, 4])
# Labels: tensor([2, 7, 0, 4])
# Labels: tensor([1, 8, 4, 2])
# Labels: tensor([7, 7, 8, 4])
# Labels: tensor([3, 6, 6, 2])
# Labels: tensor([4, 8, 2, 3])
# Labels: tensor([8, 1, 3, 4])
# Labels: tensor([3, 4, 6, 4])
# Labels: tensor([0, 2, 3, 9])
# Labels: tensor([9, 1, 9, 0])
# Labels: tensor([0, 9, 8, 0])
# Labels: tensor([6, 9, 6, 0])
# Labels: tensor([0, 4, 6, 8])
# Labels: tensor([2, 3, 3, 5])
# Labels: tensor([5, 5, 5, 7])
# Labels: tensor([3, 6, 5, 4])
# Labels: tensor([7, 0, 3, 8])
# Labels: tensor([9, 4, 6, 0])
# Labels: tensor([9, 3, 9, 3])
# Labels: tensor([7, 0, 0, 3])
# Labels: tensor([8, 5, 7, 3])
# Labels: tensor([4, 7, 9, 8])
# Labels: tensor([5, 0, 7, 3])
# Labels: tensor([8, 8, 6, 1])
# Labels: tensor([3, 8, 7, 5])
# Labels: tensor([9, 5, 2, 8])
# Labels: tensor([4, 9, 6, 6])
# Labels: tensor([6, 0, 2, 4])
# Labels: tensor([4, 9, 5, 6])
# Labels: tensor([2, 4, 5, 3])
# Labels: tensor([8, 8, 2, 5])
# Labels: tensor([4, 5, 4, 2])
# Labels: tensor([0, 6, 1, 4])
# Labels: tensor([1, 8, 0, 8])
# Labels: tensor([9, 3, 4, 2])
# Labels: tensor([1, 5, 7, 2])
# Labels: tensor([8, 0, 1, 2])
# Labels: tensor([9, 8, 1, 5])
# Labels: tensor([0, 9, 9, 9])
# Labels: tensor([9, 8, 2, 6])
# Labels: tensor([2, 6, 6, 1])
# Labels: tensor([8, 1, 4, 6])
# Labels: tensor([7, 1, 0, 7])
# Labels: tensor([3, 6, 6, 4])
# Labels: tensor([9, 3, 8, 8])
# Labels: tensor([2, 2, 9, 6])
# Labels: tensor([5, 5, 3, 7])
# Labels: tensor([1, 8, 6, 0])
# Labels: tensor([1, 5, 5, 2])
# Labels: tensor([1, 9, 5, 7])
# Labels: tensor([8, 4, 8, 2])
# Labels: tensor([1, 2, 1, 7])
# Labels: tensor([9, 8, 2, 2])
# Labels: tensor([6, 7, 2, 6])
# Labels: tensor([8, 8, 3, 6])
# Labels: tensor([7, 2, 0, 5])
# Labels: tensor([2, 3, 6, 9])
# Labels: tensor([0, 3, 6, 7])
# Labels: tensor([5, 6, 4, 8])
# Labels: tensor([5, 3, 9, 5])
# Labels: tensor([6, 0, 2, 0])
# Labels: tensor([9, 3, 5, 6])
# Labels: tensor([5, 1, 3, 5])
# Labels: tensor([5, 5, 8, 7])
# Labels: tensor([6, 3, 4, 1])
# Labels: tensor([8, 5, 7, 8])
# Labels: tensor([3, 8, 2, 0])
# Labels: tensor([1, 0, 2, 8])
# Labels: tensor([2, 2, 6, 4])
# Labels: tensor([5, 0, 8, 9])
# Labels: tensor([8, 1, 5, 5])
# Labels: tensor([7, 3, 1, 1])
# Labels: tensor([0, 6, 6, 9])
# Labels: tensor([0, 2, 3, 6])
# Labels: tensor([1, 0, 5, 2])
# Labels: tensor([4, 9, 0, 1])

# %%
class NetWithDropout(nn.Module):
        def __init__(self):
            super(NetWithDropout, self).__init__()
            # Define convolutional layers
            self.conv1 = nn.Conv2d(3, 10, 3) 
            self.conv2 = nn.Conv2d(10, 16, 3)
            # Define pooling layer
            self.pool = nn.MaxPool2d(2, 2) # 2x2 max pooling
            self.dropout = nn.Dropout(0.5)
            # Define fully connected layers
            self.fc1 = nn.Linear(16 * 6 * 6, 120) 
            self.fc2 = nn.Linear(120, 84)
            self.fc3 = nn.Linear(84, 10) 

        def forward(self, x):
            # Define the forward pass
            x = self.pool(F.relu(self.conv1(x))) # Convolution -> Activation -> Pooling
            x = self.pool(F.relu(self.conv2(x)))
            x = x.view(-1, 16 * 6* 6) # Flatten the tensor for the fully connected layer
            x = F.relu(self.fc1(x))
            x = self.dropout(x) 
            x = F.relu(self.fc2(x))
            x = self.dropout(x) 
            x = self.fc3(x)
            return x

net_with_dropout = NetWithDropout()

# %%
for param in net_with_dropout.parameters():
    print(param)
# Out:
# Parameter containing:
# tensor([[[[-0.0656, -0.1578, -0.1173],
#           [ 0.0849, -0.0255,  0.0590],
#           [-0.1783, -0.1130, -0.1684]],
#
#          [[-0.0360,  0.1559,  0.1867],
#           [-0.1551,  0.0948, -0.1121],
#           [ 0.1719, -0.0646,  0.1419]],
#
#          [[-0.0192,  0.0611, -0.1073],
#           [-0.0019,  0.0006,  0.1143],
#           [ 0.0272, -0.0640,  0.0955]]],
#
#
#         [[[ 0.0871,  0.1583,  0.0013],
#           [ 0.1405,  0.0320,  0.0260],
#           [ 0.1246, -0.0492, -0.0773]],
#
#          [[-0.0308,  0.0466, -0.1397],
#           [-0.0008,  0.0383, -0.0662],
#           [-0.0910,  0.1194, -0.0710]],
#
#          [[ 0.0122, -0.1773,  0.1532],
#           [ 0.1923, -0.1260,  0.1730],
#           [-0.0375, -0.0035, -0.1012]]],
#
#
#         [[[-0.1611, -0.1830, -0.0356],
#           [-0.1251, -0.0254,  0.0974],
#           [ 0.1731, -0.0454,  0.0451]],
#
#          [[-0.0413,  0.0860, -0.1800],
#           [ 0.0139, -0.0233, -0.0259],
#           [ 0.0236, -0.0838, -0.0650]],
#
#          [[ 0.0580,  0.1162, -0.1618],
#           [-0.1916,  0.1552,  0.0568],
#           [ 0.0748, -0.0086,  0.0872]]],
#
#
#         [[[ 0.1014, -0.0760, -0.1112],
#           [ 0.1144, -0.1906, -0.0960],
#           [-0.1868,  0.0077,  0.1138]],
#
#          [[ 0.0237,  0.0109,  0.1627],
#           [-0.1074, -0.1309,  0.0552],
#           [-0.1278, -0.0328, -0.0237]],
#
#          [[-0.0364, -0.1666,  0.1817],
#           [ 0.1291, -0.1601, -0.1292],
#           [-0.1402, -0.1231, -0.0924]]],
#
#
#         [[[-0.0032, -0.1594,  0.0453],
#           [-0.1068,  0.1765, -0.1070],
#           [ 0.0341, -0.0378, -0.1860]],
#
#          [[-0.1404, -0.1706,  0.0429],
#           [ 0.0116, -0.1516,  0.1448],
#           [-0.0910,  0.1085,  0.1237]],
#
#          [[ 0.1763, -0.0324,  0.1044],
#           [-0.0116, -0.0661, -0.0445],
#           [ 0.0133, -0.1857,  0.0643]]],
#
#
#         [[[ 0.0707,  0.1830,  0.0526],
#           [-0.0206, -0.1374, -0.0642],
#           [-0.0526, -0.0311,  0.1219]],
#
#          [[ 0.1110,  0.0050,  0.0358],
#           [-0.1696, -0.1436, -0.1346],
#           [-0.1450, -0.1411,  0.1750]],
#
#          [[-0.0513,  0.1474,  0.0247],
#           [ 0.1273, -0.0861, -0.0863],
#           [-0.1347,  0.0104, -0.0088]]],
#
#
#         [[[-0.0903, -0.0856, -0.1710],
#           [-0.0516, -0.0489, -0.1495],
#           [ 0.0039,  0.0630, -0.1071]],
#
#          [[ 0.1044, -0.1693, -0.0629],
#           [-0.1546, -0.0285,  0.0302],
#           [ 0.1446,  0.0593, -0.1264]],
#
#          [[ 0.1884, -0.0700,  0.1321],
#           [ 0.1308,  0.1069, -0.0472],
#           [ 0.1620, -0.0993,  0.0776]]],
#
#
#         [[[-0.0347, -0.0836, -0.1087],
#           [-0.1552, -0.0541, -0.1009],
#           [-0.0768,  0.1042, -0.0095]],
#
#          [[ 0.1742,  0.0522,  0.1150],
#           [-0.1216, -0.1184, -0.0299],
#           [-0.0432, -0.0390,  0.0318]],
#
#          [[ 0.0442, -0.0462, -0.0495],
#           [-0.1625,  0.1553,  0.1022],
#           [ 0.0461,  0.1889,  0.0475]]],
#
#
#         [[[ 0.1003,  0.1745, -0.1911],
#           [-0.0883,  0.1792, -0.0458],
#           [ 0.0732,  0.0458, -0.1872]],
#
#          [[-0.1418, -0.1126, -0.1746],
#           [ 0.1159,  0.1766, -0.1059],
#           [-0.1179,  0.0687,  0.1625]],
#
#          [[ 0.0501,  0.0782,  0.1709],
#           [ 0.0740, -0.0972, -0.1742],
#           [ 0.0647,  0.1917, -0.0449]]],
#
#
#         [[[-0.0016,  0.0226,  0.0398],
#           [-0.0186, -0.0122,  0.1335],
#           [-0.0122,  0.0205, -0.1627]],
#
#          [[ 0.0589, -0.0298,  0.0760],
#           [ 0.1261, -0.1724, -0.1740],
#           [-0.1175, -0.1796, -0.0992]],
#
#          [[-0.1363, -0.0944, -0.1036],
#           [-0.1325,  0.1725,  0.1227],
#           [ 0.0321,  0.0623, -0.0833]]]], requires_grad=True)
# Parameter containing:
# tensor([-0.1277,  0.0646, -0.1569,  0.0252, -0.0215, -0.1738,  0.0754,  0.0927,
#         -0.0253, -0.1352], requires_grad=True)
# Parameter containing:
# tensor([[[[ 8.0160e-02, -8.1366e-02,  1.5255e-02],
#           [ 8.0223e-03,  8.4890e-02, -4.1786e-02],
#           [ 8.5737e-02,  5.4582e-02,  5.1380e-02]],
#
#          [[ 1.8063e-02,  9.5241e-02,  8.8467e-02],
#           [ 6.8335e-02, -8.4201e-02,  9.6552e-02],
#           [-5.7405e-02,  2.1977e-02,  5.2841e-02]],
#
#          [[ 9.4231e-02,  3.3346e-02,  6.7051e-02],
#           [ 1.9022e-02, -4.8308e-02, -7.8357e-02],
#           [-8.9999e-02,  6.3564e-02,  5.5301e-02]],
#
#          ...,
#
#          [[ 6.9594e-02, -8.0321e-02, -5.2637e-02],
#           [-8.8950e-02, -6.9546e-03,  5.4967e-02],
#           [-9.5810e-02,  4.5920e-02, -6.0481e-02]],
#
#          [[ 6.3282e-03,  1.0211e-01, -1.6789e-03],
#           [-3.6545e-02,  8.5022e-02, -5.1707e-02],
#           [ 7.3761e-02,  6.2460e-02, -6.2000e-02]],
#
#          [[ 5.5029e-02, -1.0450e-01,  5.7142e-02],
#           [ 2.2013e-02, -1.5638e-02, -6.3256e-03],
#           [ 2.9962e-02,  1.0457e-01, -4.9789e-02]]],
#
#
#         [[[-7.3154e-02, -4.7016e-02, -7.4269e-02],
#           [-1.4146e-02,  8.0529e-02, -8.9179e-03],
#           [-5.3624e-03, -2.8215e-02, -6.2509e-02]],
#
#          [[ 5.2451e-02,  2.7756e-04,  3.6399e-02],
#           [ 3.1297e-02, -7.3379e-02, -3.2394e-02],
#           [ 2.9717e-02, -3.0096e-02, -8.3351e-02]],
#
#          [[-9.4970e-02,  6.9306e-02, -8.0765e-03],
#           [ 1.9408e-02,  2.1831e-02, -2.0655e-02],
#           [ 1.0855e-02,  9.8806e-02,  7.6491e-02]],
#
#          ...,
#
#          [[-3.1351e-02, -4.9864e-02, -9.6727e-02],
#           [ 1.0216e-02,  4.5938e-02,  1.6268e-02],
#           [ 5.6486e-02,  1.9835e-02, -2.0234e-02]],
#
#          [[ 8.1175e-02,  3.1018e-02,  8.9345e-02],
#           [-6.7786e-02, -3.5895e-04, -5.5260e-02],
#           [-2.3999e-02,  2.2161e-02,  5.0754e-02]],
#
#          [[ 2.7169e-02,  8.9739e-02, -2.4098e-02],
#           [ 7.4374e-02, -9.3123e-02,  6.1010e-02],
#           [-6.2575e-02, -3.3363e-02,  8.9231e-02]]],
#
#
#         [[[-3.0204e-02, -1.0482e-01,  3.7758e-02],
#           [ 8.1051e-02, -1.6574e-02,  4.5260e-02],
#           [-3.3592e-02,  6.1667e-02, -1.0081e-01]],
#
#          [[-9.3917e-02,  8.4806e-03,  1.0530e-01],
#           [ 3.6849e-02,  1.0149e-01,  7.3351e-02],
#           [ 5.7132e-02,  3.0730e-02,  7.8741e-02]],
#
#          [[-4.9064e-02,  6.7782e-02,  9.0458e-03],
#           [-5.6710e-02, -1.6973e-02,  2.4224e-02],
#           [-2.1561e-02, -9.1001e-02, -2.5310e-02]],
#
#          ...,
#
#          [[ 1.1510e-02,  1.7719e-02,  1.8211e-02],
#           [ 2.3524e-02,  6.5954e-02,  5.3759e-02],
#           [-9.6790e-02,  1.0359e-01, -2.6888e-02]],
#
#          [[-4.1746e-02,  8.9863e-02, -8.2403e-02],
#           [-7.6558e-02,  1.3939e-02, -6.2042e-02],
#           [ 9.4329e-02,  6.4400e-02, -1.1979e-02]],
#
#          [[ 5.4935e-02,  9.6483e-02, -1.9172e-02],
#           [ 1.0312e-01,  3.4619e-02, -6.0655e-02],
#           [-5.7104e-02,  6.9408e-02, -1.2430e-02]]],
#
#
#         ...,
#
#
#         [[[-6.1900e-02, -1.1633e-02,  6.3328e-02],
#           [-7.1479e-02, -3.3379e-02,  4.6935e-02],
#           [-8.7839e-02, -4.8997e-02,  8.7233e-02]],
#
#          [[-1.0158e-01, -5.4287e-02, -9.6386e-02],
#           [-1.3294e-02, -1.5129e-02,  9.6227e-02],
#           [ 8.5886e-02, -4.0824e-02, -5.1435e-02]],
#
#          [[-9.2824e-02, -2.9540e-02, -3.3999e-02],
#           [-4.3532e-02,  4.8318e-02,  1.1311e-02],
#           [ 2.9310e-02, -5.0579e-02, -7.8413e-02]],
#
#          ...,
#
#          [[-4.3357e-02, -8.6574e-02, -9.8266e-02],
#           [-7.6091e-02, -8.5515e-02, -3.4900e-02],
#           [-3.5668e-02, -4.8132e-02,  2.4593e-02]],
#
#          [[-8.2857e-02,  9.1185e-02,  7.0982e-02],
#           [-8.3309e-02,  1.6955e-02, -9.6489e-02],
#           [-4.2661e-02,  8.1125e-02,  9.0515e-02]],
#
#          [[ 4.0483e-02, -4.7203e-02, -4.4221e-02],
#           [-2.2740e-02,  5.3745e-02,  4.1372e-03],
#           [ 9.4772e-03,  5.8032e-02,  3.9948e-02]]],
#
#
#         [[[ 1.0275e-01, -9.9609e-02,  1.0027e-01],
#           [ 7.1137e-02,  4.4205e-02, -3.4512e-02],
#           [-5.3894e-02,  8.6998e-03,  2.4878e-02]],
#
#          [[-4.5719e-02,  5.3957e-05,  4.6464e-02],
#           [-1.0332e-01, -6.3335e-02,  5.5380e-02],
#           [ 4.0135e-02,  8.3032e-02, -2.6626e-02]],
#
#          [[-1.0508e-01, -9.7884e-02,  8.7940e-02],
#           [-7.8529e-02, -7.7068e-02, -8.2347e-02],
#           [-7.6241e-02, -2.7367e-02, -5.8110e-02]],
#
#          ...,
#
#          [[ 3.1119e-02, -1.1249e-02,  8.1982e-02],
#           [-6.0661e-03, -8.2491e-02,  5.2038e-02],
#           [ 4.7582e-02, -3.2443e-02, -7.4104e-02]],
#
#          [[ 2.9235e-02, -7.9420e-02, -3.6696e-02],
#           [-9.8563e-02, -1.5695e-02, -8.7055e-02],
#           [ 1.1998e-02, -1.0439e-01,  2.4428e-02]],
#
#          [[-8.9321e-02, -7.6818e-02, -3.8283e-02],
#           [ 4.0152e-02, -6.9460e-02,  9.5794e-02],
#           [-1.0409e-01, -2.5220e-02, -8.2120e-02]]],
#
#
#         [[[-3.8951e-02,  5.9253e-02,  1.6947e-02],
#           [ 7.3919e-02, -5.9238e-02,  9.7518e-03],
#           [ 4.5254e-02,  1.6113e-02,  5.6651e-02]],
#
#          [[-3.3114e-03, -5.0999e-02,  8.8478e-02],
#           [-7.5668e-02, -6.8328e-02,  4.2742e-02],
#           [ 5.8998e-02,  5.4894e-02, -9.3179e-02]],
#
#          [[ 4.3861e-02, -3.7546e-02, -8.9350e-02],
#           [-2.2429e-02,  3.2237e-02, -8.7819e-02],
#           [ 2.7848e-02,  2.6500e-03, -3.7909e-02]],
#
#          ...,
#
#          [[ 1.0483e-01, -1.0665e-04,  1.4122e-02],
#           [ 7.1215e-02,  2.9457e-02,  5.2540e-02],
#           [-3.7767e-02,  7.5673e-03, -2.8655e-02]],
#
#          [[-7.5248e-02, -1.8225e-02, -8.1357e-02],
#           [-1.0408e-01, -7.7104e-02,  9.7613e-02],
#           [-3.4392e-02, -6.4716e-02,  1.4828e-02]],
#
#          [[-3.4585e-02,  2.8901e-02,  4.0308e-02],
#           [-3.6925e-02,  2.8085e-02, -5.4927e-02],
#           [-2.4450e-02, -1.7687e-03,  7.0549e-03]]]], requires_grad=True)
# Parameter containing:
# tensor([-0.0384,  0.0753, -0.0544,  0.0630,  0.0235,  0.0341,  0.0041,  0.0832,
#          0.0541,  0.0510,  0.1042, -0.0207,  0.0415, -0.0085, -0.0539,  0.0330],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.0566,  0.0685, -0.0060,  ...,  0.0464,  0.0086, -0.0578],
#         [-0.0018,  0.0168,  0.0804,  ..., -0.0164,  0.0476, -0.0545],
#         [ 0.0651, -0.0290, -0.0247,  ..., -0.0316,  0.0155,  0.0667],
#         ...,
#         [-0.0321, -0.0715,  0.0680,  ..., -0.0805,  0.0531, -0.0429],
#         [ 0.0211, -0.0484, -0.0355,  ...,  0.0136, -0.0483,  0.0746],
#         [-0.0831, -0.0124,  0.0459,  ...,  0.0460,  0.0480, -0.0115]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 7.4227e-02,  2.6441e-02,  1.7263e-02, -2.1780e-02, -2.9586e-02,
#         -3.7279e-02, -2.1416e-02, -4.4968e-02,  1.2717e-02, -2.9967e-02,
#          2.0322e-02,  8.0549e-02,  8.1875e-02, -4.7514e-02, -7.5706e-02,
#         -7.7245e-02,  5.0996e-02, -4.4936e-02,  1.8012e-02, -2.5321e-02,
#          5.7313e-02, -4.5465e-02, -7.6448e-02,  7.2285e-02,  1.7034e-02,
#          1.9950e-02,  4.2223e-02, -7.4903e-02,  2.5490e-02, -5.2744e-02,
#          8.6207e-03, -6.0999e-02,  2.4964e-02,  6.4664e-02,  2.4723e-02,
#         -2.0816e-02, -7.1073e-03, -5.1781e-02,  6.6722e-02,  1.5398e-02,
#         -6.6285e-02,  7.3208e-02, -5.6525e-02, -6.4945e-02,  2.4294e-02,
#          3.8656e-02, -6.5269e-02, -5.1757e-02,  3.6981e-03, -7.7701e-03,
#         -7.5073e-02, -7.9460e-02,  6.2772e-02,  1.3261e-04,  2.9284e-04,
#         -5.8100e-02,  7.9777e-02,  1.9125e-02, -6.9654e-02,  7.9712e-03,
#          6.7881e-02,  2.0916e-02,  7.7811e-02, -8.2029e-02, -1.8643e-02,
#         -6.7927e-02,  4.5893e-02,  2.2304e-03,  7.5426e-02,  8.1575e-02,
#         -3.3480e-02, -3.2549e-02,  8.2831e-02,  2.7073e-02, -3.0194e-02,
#         -4.8897e-02,  3.6634e-02, -1.7914e-02,  6.9816e-02,  7.6051e-02,
#         -3.8880e-02,  5.4708e-02, -6.8395e-02,  4.0916e-02,  6.1547e-02,
#          6.1299e-02,  4.7217e-02,  5.8197e-02,  1.9071e-03,  4.7522e-02,
#         -1.3228e-02,  8.3551e-03,  5.7297e-02, -3.5727e-02,  4.5122e-02,
#          9.4354e-05, -3.6712e-02, -6.1677e-02, -5.0923e-02, -3.0375e-02,
#          2.6685e-02,  4.3413e-02,  7.5910e-02,  7.3057e-02,  5.0394e-02,
#         -5.4992e-03, -2.3782e-02,  3.8979e-02, -2.5936e-02, -3.1675e-02,
#         -3.8666e-02, -3.9308e-02,  4.6103e-02, -1.9287e-02, -2.1553e-02,
#          5.8151e-02,  5.9218e-02, -1.2225e-02, -2.8061e-02, -3.5117e-02],
#        requires_grad=True)
# Parameter containing:
# tensor([[-0.0556, -0.0438,  0.0216,  ..., -0.0020,  0.0389, -0.0755],
#         [ 0.0249,  0.0893,  0.0430,  ...,  0.0055, -0.0238,  0.0565],
#         [ 0.0110, -0.0387,  0.0852,  ..., -0.0623, -0.0554,  0.0379],
#         ...,
#         [-0.0906,  0.0029,  0.0413,  ...,  0.0531,  0.0073, -0.0619],
#         [-0.0892, -0.0805, -0.0898,  ..., -0.0165, -0.0672,  0.0664],
#         [ 0.0766, -0.0151,  0.0606,  ..., -0.0299,  0.0144,  0.0206]],
#        requires_grad=True)
# Parameter containing:
# tensor([ 0.0333, -0.0752, -0.0847, -0.0783,  0.0801, -0.0709,  0.0529,  0.0383,
#          0.0166,  0.0575, -0.0210,  0.0767,  0.0357,  0.0669,  0.0041,  0.0607,
#          0.0523,  0.0633,  0.0573, -0.0912, -0.0406,  0.0881, -0.0882, -0.0391,
#          0.0247,  0.0117, -0.0300, -0.0330,  0.0006, -0.0358,  0.0155,  0.0384,
#          0.0286, -0.0461, -0.0318, -0.0594,  0.0620,  0.0854, -0.0107,  0.0026,
#         -0.0436, -0.0035, -0.0117,  0.0715, -0.0362,  0.0784,  0.0155, -0.0042,
#          0.0903,  0.0798,  0.0101,  0.0900,  0.0190, -0.0546,  0.0880, -0.0655,
#         -0.0513, -0.0654, -0.0455, -0.0309, -0.0282,  0.0108, -0.0216,  0.0134,
#          0.0777,  0.0638,  0.0788,  0.0827, -0.0670, -0.0522,  0.0222,  0.0709,
#         -0.0737, -0.0428, -0.0541, -0.0576,  0.0880,  0.0540, -0.0349,  0.0447,
#         -0.0383, -0.0591, -0.0185, -0.0533], requires_grad=True)
# Parameter containing:
# tensor([[ 0.0492,  0.0461,  0.0102,  0.0595,  0.0972, -0.0769, -0.0545, -0.0124,
#           0.0260,  0.0983, -0.0902,  0.0456, -0.0761,  0.0182, -0.0872, -0.0619,
#          -0.0342,  0.0374,  0.1003,  0.0530, -0.0912,  0.0801,  0.0992,  0.0451,
#           0.0538, -0.0632,  0.0377, -0.0545,  0.0256, -0.0407,  0.0317,  0.0142,
#           0.0394, -0.0175, -0.0958,  0.0652,  0.0194,  0.0746,  0.0959, -0.0784,
#           0.0708,  0.1091, -0.0321,  0.0294,  0.0882, -0.0563,  0.0104,  0.0477,
#           0.0109,  0.0452, -0.0211,  0.0330, -0.0358, -0.0348, -0.0289, -0.1028,
#           0.0550,  0.0195, -0.0443, -0.0477, -0.0066, -0.0267, -0.0116,  0.0130,
#           0.0969,  0.0249, -0.0418, -0.0425,  0.0045,  0.0654,  0.0895, -0.0598,
#          -0.0422, -0.0030,  0.0371, -0.0658,  0.0765,  0.1072,  0.0173, -0.1001,
#           0.0890,  0.0241,  0.0717, -0.0846],
#         [-0.0973,  0.0480, -0.0094,  0.0795, -0.0503, -0.0129, -0.0786, -0.0389,
#           0.0801,  0.1070, -0.0961,  0.1072,  0.0092,  0.0884, -0.0006, -0.0100,
#          -0.0812, -0.0043,  0.0568,  0.0328, -0.1026,  0.0495, -0.0901, -0.0953,
#          -0.0071,  0.0010, -0.0369, -0.0318,  0.0867, -0.0070,  0.0505,  0.0311,
#           0.0495,  0.0770, -0.0415, -0.0540,  0.0101, -0.0946, -0.0830,  0.0051,
#           0.0620, -0.0556, -0.0329,  0.0799, -0.0289, -0.0758,  0.0360,  0.0377,
#           0.0080, -0.0922,  0.0053,  0.1021,  0.0463, -0.0843,  0.0921,  0.0637,
#          -0.0831, -0.0141,  0.0532,  0.0758, -0.0137, -0.0956,  0.0932,  0.0046,
#          -0.0237,  0.0807,  0.0418,  0.1046, -0.0913, -0.0362, -0.0583, -0.0547,
#           0.0679, -0.0677,  0.1056, -0.0237,  0.0354, -0.0388,  0.0608,  0.0148,
#           0.0973, -0.1057, -0.0977, -0.0016],
#         [ 0.0031,  0.0926,  0.1081,  0.0798, -0.0696, -0.0670, -0.1059, -0.0212,
#          -0.1016, -0.0170,  0.0122, -0.0522, -0.0237, -0.0585,  0.0836, -0.0142,
#           0.0631,  0.0798,  0.0996, -0.0003, -0.0360, -0.0658,  0.0066, -0.0674,
#           0.0590,  0.0853,  0.0935, -0.0109,  0.1084,  0.0116,  0.0519,  0.0582,
#           0.0197,  0.0604, -0.0514,  0.0098, -0.0433,  0.0172,  0.1015,  0.0560,
#           0.0856, -0.0700, -0.0642,  0.0803, -0.0436, -0.0246, -0.0303, -0.0300,
#          -0.0226,  0.0775,  0.0077, -0.0283,  0.0862,  0.0043,  0.0601, -0.0087,
#          -0.0552,  0.0881,  0.0622, -0.0146, -0.0013, -0.0188, -0.0514,  0.0275,
#          -0.0895, -0.0393, -0.0050, -0.0294, -0.0574, -0.0496,  0.0357, -0.0973,
#           0.0896, -0.0003,  0.0346, -0.0723,  0.0865,  0.0533,  0.0890, -0.0626,
#           0.0751,  0.1066, -0.0328,  0.0424],
#         [-0.0425,  0.0727,  0.0480,  0.0853, -0.0108, -0.0504,  0.0742,  0.0946,
#          -0.0799, -0.0816, -0.0981,  0.0321,  0.1027, -0.0011,  0.0272, -0.0416,
#           0.0614,  0.0261,  0.1049,  0.0122,  0.0212,  0.0101, -0.0007,  0.0775,
#           0.0677,  0.0197, -0.0233, -0.0724,  0.0085,  0.0625,  0.0123,  0.1030,
#          -0.0663, -0.0189, -0.0159, -0.1076, -0.0071, -0.0115,  0.0479, -0.0015,
#          -0.1042,  0.0434, -0.0444,  0.0054, -0.0496,  0.0248,  0.0852,  0.0580,
#           0.0677,  0.0757,  0.0043,  0.0834, -0.0277, -0.1070, -0.0018, -0.0004,
#           0.0622, -0.0843,  0.0622, -0.0653,  0.0562,  0.0010,  0.0797,  0.0261,
#          -0.0257, -0.0169, -0.0732, -0.0013,  0.0837,  0.1026,  0.0668, -0.0477,
#          -0.0437,  0.0372,  0.1049,  0.0393, -0.0223,  0.0764, -0.0577, -0.0408,
#          -0.0861,  0.0969, -0.0832, -0.1035],
#         [-0.0260,  0.0943, -0.0817, -0.0195,  0.0984, -0.0531,  0.0671,  0.0787,
#          -0.0516, -0.0164, -0.0059, -0.0026,  0.0737,  0.0398, -0.0317, -0.0352,
#          -0.0054, -0.0253, -0.0150,  0.0985,  0.0610,  0.1036,  0.0758,  0.0849,
#          -0.0608,  0.0450,  0.0265, -0.1076,  0.0931,  0.0295, -0.0083,  0.0323,
#          -0.0282,  0.0404, -0.0345,  0.0558, -0.0149,  0.1033,  0.0472,  0.0985,
#           0.0646,  0.0216, -0.0841, -0.0381,  0.0678,  0.0779,  0.0882,  0.0958,
#          -0.0288,  0.0240, -0.0155, -0.0168,  0.0661, -0.0023, -0.0757, -0.0982,
#          -0.0451,  0.0113, -0.0011,  0.0523,  0.0336,  0.0557,  0.0672, -0.0137,
#           0.0812, -0.0859, -0.0476, -0.1024,  0.0173,  0.0205, -0.0823, -0.0897,
#           0.0973,  0.0616, -0.0369, -0.0883,  0.0446,  0.0883, -0.0358, -0.0439,
#           0.0387, -0.0448, -0.0406, -0.0817],
#         [ 0.0754,  0.0494, -0.0999, -0.0591, -0.0761, -0.0025,  0.0449,  0.0658,
#          -0.0499, -0.0564,  0.0278,  0.1052,  0.0917,  0.0177,  0.0783,  0.0346,
#           0.0271,  0.0451, -0.0564, -0.0636, -0.0431,  0.0824, -0.0065,  0.0810,
#          -0.0599, -0.0373,  0.0569,  0.0215,  0.0352,  0.0518, -0.0326,  0.0623,
#           0.0019,  0.0520,  0.0067,  0.1037,  0.0767, -0.0486,  0.0532,  0.0286,
#           0.0264,  0.0451, -0.0008,  0.0044, -0.0024,  0.0748,  0.0562,  0.0428,
#           0.0296, -0.0284,  0.0623,  0.0727, -0.0686,  0.0594,  0.0001, -0.0769,
#           0.0050,  0.0121, -0.1007,  0.0307,  0.0871, -0.0863,  0.0543,  0.1046,
#           0.0662,  0.1084, -0.0607,  0.0474,  0.0478,  0.0166,  0.0566,  0.0569,
#           0.0859,  0.0213, -0.0231, -0.1047, -0.0152,  0.0673,  0.0116,  0.0755,
#           0.0557, -0.0492, -0.0022,  0.0812],
#         [-0.0201, -0.0075, -0.0586, -0.0799,  0.0099,  0.0261, -0.0339, -0.0188,
#           0.0069,  0.0419, -0.0538, -0.0353,  0.0377,  0.0584,  0.0728,  0.0166,
#           0.0623, -0.0295,  0.0042,  0.0155, -0.0275, -0.0896, -0.0937, -0.0501,
#          -0.0740, -0.0423,  0.0513, -0.0019,  0.0427,  0.0515,  0.0365, -0.0666,
#          -0.0473, -0.0293, -0.0632,  0.0412,  0.0061, -0.0821, -0.0798, -0.0904,
#          -0.0548, -0.1027, -0.0614,  0.0057, -0.0323,  0.0654, -0.0492,  0.0458,
#           0.0895,  0.0969, -0.0147,  0.0800, -0.0881,  0.0442, -0.0777,  0.1081,
#          -0.0788, -0.1059,  0.0482,  0.0017,  0.0389,  0.0400, -0.0414, -0.0178,
#          -0.0852, -0.0679, -0.0152, -0.0881, -0.0126, -0.0108,  0.1038,  0.0843,
#          -0.0406, -0.0785, -0.0008, -0.0201,  0.0755,  0.0759, -0.1010, -0.0884,
#          -0.0855, -0.0592,  0.0528, -0.0059],
#         [-0.0547,  0.0609, -0.0404,  0.0124,  0.0431, -0.0422,  0.0826,  0.1027,
#           0.0571,  0.0650, -0.0250, -0.0118,  0.0300,  0.0663, -0.0044, -0.0293,
#          -0.0927, -0.0570,  0.0113, -0.0374, -0.0423,  0.0659,  0.0654,  0.0908,
#          -0.0675,  0.0062,  0.0880,  0.0060, -0.1007,  0.1050, -0.0473,  0.1020,
#          -0.0330,  0.0944, -0.0786, -0.0689,  0.0578, -0.0685,  0.0344,  0.0743,
#           0.0603, -0.0604, -0.0666, -0.0593, -0.0899, -0.0730, -0.0521,  0.0967,
#           0.0832, -0.0942,  0.1014,  0.0991, -0.0680,  0.0970, -0.0781,  0.0917,
#           0.0662,  0.0060,  0.0014, -0.0793,  0.0043,  0.0546,  0.0622,  0.0432,
#           0.0588, -0.0776, -0.0654,  0.0861,  0.0840,  0.0987,  0.0967, -0.0331,
#          -0.0432,  0.0054, -0.0472,  0.0474, -0.0841,  0.0613, -0.0675, -0.0136,
#           0.0998,  0.0367, -0.0182,  0.0659],
#         [ 0.0528, -0.0901, -0.0213, -0.0328, -0.0013,  0.0378,  0.0523,  0.0603,
#          -0.0299,  0.0526,  0.0007, -0.0351,  0.0862,  0.0293, -0.0025, -0.0176,
#           0.0680,  0.0986, -0.0633, -0.0779,  0.0146, -0.0988,  0.0599,  0.0534,
#           0.1055,  0.0851, -0.0840,  0.0973,  0.0052,  0.0305, -0.0199,  0.0953,
#          -0.0081,  0.0542, -0.0735, -0.0159,  0.0086, -0.0505,  0.0536,  0.0857,
#          -0.0035,  0.0514,  0.0664, -0.0185,  0.0973,  0.0768, -0.0555, -0.0428,
#           0.0332, -0.0404,  0.0612,  0.0248,  0.0652,  0.0843, -0.0820, -0.0891,
#           0.0417,  0.0291,  0.0708,  0.0153,  0.0281,  0.0918,  0.0070,  0.0003,
#           0.0538,  0.1033,  0.0222,  0.0215,  0.0901, -0.0996,  0.0351,  0.0031,
#          -0.0776,  0.0923, -0.0714, -0.0791,  0.0515, -0.0553,  0.0807,  0.0633,
#          -0.0726, -0.0035, -0.0065,  0.0856],
#         [-0.0673,  0.0695,  0.0370, -0.0252, -0.0742,  0.0479,  0.0291,  0.0039,
#          -0.0337, -0.0259,  0.0794, -0.0486,  0.0709, -0.1013, -0.0376, -0.0989,
#          -0.0574, -0.0953,  0.0973, -0.0641,  0.0517, -0.0033,  0.0687,  0.1059,
#          -0.0669, -0.0956,  0.0630,  0.0917, -0.0150,  0.0241, -0.0610,  0.0853,
#          -0.0390, -0.0472, -0.0201, -0.0251,  0.0956,  0.0573,  0.0919, -0.0752,
#           0.0103,  0.0368,  0.0330, -0.0560,  0.0714, -0.0596,  0.0538,  0.1071,
#          -0.0885, -0.0467,  0.0793, -0.0267, -0.0402, -0.0067,  0.0926, -0.0246,
#           0.0018,  0.0892,  0.0715, -0.0980,  0.1002, -0.0288,  0.0123, -0.0422,
#          -0.1081,  0.0363, -0.0726, -0.0404,  0.0554,  0.0944,  0.0458,  0.0246,
#          -0.0251, -0.0177, -0.0836,  0.0047,  0.0946, -0.0288, -0.1074, -0.0535,
#          -0.0372, -0.0684, -0.1043,  0.0682]], requires_grad=True)
# Parameter containing:
# tensor([ 0.0559,  0.0429, -0.0593, -0.0696, -0.0251, -0.0481, -0.0410, -0.0796,
#          0.0096,  0.0319], requires_grad=True)

# %%
# Optimizers
optimizer_sgd_with_dropout = torch.optim.SGD(net_with_dropout.parameters(), lr=0.001, momentum=0.9)
optimizer_sgd_without_dropout = torch.optim.SGD(net_without_dropout.parameters(), lr=0.001, momentum=0.9)
optimizer_adam_with_dropout = torch.optim.Adam(net_with_dropout.parameters(), lr=0.001)
optimizer_adam_without_dropout = torch.optim.Adam(net_without_dropout.parameters(), lr=0.001)

# %% [markdown]
# ## Training

# %%
num_epochs = 20

# %%
def train_model(model, optimizer, num_epochs, trainloader, valloader):
    for epoch in range(num_epochs):
        # Training phase
        model.train()  # Set the model to training mode
        running_loss = 0.0
        for inputs, labels in trainloader:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        # Validation phase
        model.eval()  # Set the model to evaluation mode
        val_running_loss = 0.0
        val_correct = 0
        total = 0
        with torch.no_grad():
            for inputs, labels in valloader:
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_running_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                val_correct += (predicted == labels).sum().item()

        train_loss = running_loss / len(trainloader)
        val_loss = val_running_loss / len(valloader)
        val_accuracy = 100 * val_correct / total

        print(f'Epoch {epoch+1}, Train Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.2f}%')

    print('Finished Training')

# %%
print("Training Net without Dropout using SGD")
train_model(net_without_dropout, optimizer_sgd_without_dropout,num_epochs, trainloader, valloader)

print("Training Net with Dropout using SGD")
train_model(net_with_dropout, optimizer_sgd_with_dropout,num_epochs, trainloader, valloader)

print("Training Net without Dropout using Adam")
train_model(net_without_dropout, optimizer_adam_without_dropout,num_epochs, trainloader, valloader)

print("Training Net with Dropout using Adam")
train_model(net_with_dropout, optimizer_adam_with_dropout,num_epochs, trainloader, valloader)
# Out:
# Training Net without Dropout using SGD
# Epoch 1, Train Loss: 2.3048, Validation Loss: 2.3050, Validation Accuracy: 9.58%
# Epoch 2, Train Loss: 2.3048, Validation Loss: 2.3050, Validation Accuracy: 9.58%
# Epoch 3, Train Loss: 2.3048, Validation Loss: 2.3050, Validation Accuracy: 9.58%
# Epoch 4, Train Loss: 2.3048, Validation Loss: 2.3050, Validation Accuracy: 9.58%
# Epoch 5, Train Loss: 2.3048, Validation Loss: 2.3050, Validation Accuracy: 9.58%
# Epoch 6, Train Loss: 2.3048, Validation Loss: 2.3050, Validation Accuracy: 9.58%
# Epoch 7, Train Loss: 2.3048, Validation Loss: 2.3050, Validation Accuracy: 9.58%
# Epoch 8, Train Loss: 2.3048, Validation Loss: 2.3050, Validation Accuracy: 9.58%
# Epoch 9, Train Loss: 2.3048, Validation Loss: 2.3050, Validation Accuracy: 9.58%
# Epoch 10, Train Loss: 2.3048, Validation Loss: 2.3050, Validation Accuracy: 9.58%
# Finished Training
# Training Net with Dropout using SGD
# Epoch 1, Train Loss: 2.3051, Validation Loss: 2.3042, Validation Accuracy: 10.30%
# Epoch 2, Train Loss: 2.3056, Validation Loss: 2.3042, Validation Accuracy: 10.30%
# Epoch 3, Train Loss: 2.3051, Validation Loss: 2.3042, Validation Accuracy: 10.30%
# Epoch 4, Train Loss: 2.3053, Validation Loss: 2.3042, Validation Accuracy: 10.30%
# Epoch 5, Train Loss: 2.3052, Validation Loss: 2.3042, Validation Accuracy: 10.30%
# Epoch 6, Train Loss: 2.3053, Validation Loss: 2.3042, Validation Accuracy: 10.30%
# Epoch 7, Train Loss: 2.3056, Validation Loss: 2.3042, Validation Accuracy: 10.30%
# Epoch 8, Train Loss: 2.3055, Validation Loss: 2.3042, Validation Accuracy: 10.30%
# Epoch 9, Train Loss: 2.3050, Validation Loss: 2.3042, Validation Accuracy: 10.30%
# Epoch 10, Train Loss: 2.3054, Validation Loss: 2.3042, Validation Accuracy: 10.30%
# Finished Training
# Training Net without Dropout using Adam
# Epoch 1, Train Loss: 2.3048, Validation Loss: 2.3050, Validation Accuracy: 9.58%
# Epoch 2, Train Loss: 2.3048, Validation Loss: 2.3050, Validation Accuracy: 9.58%
# Epoch 3, Train Loss: 2.3048, Validation Loss: 2.3050, Validation Accuracy: 9.58%
# Epoch 4, Train Loss: 2.3048, Validation Loss: 2.3050, Validation Accuracy: 9.58%
# Epoch 5, Train Loss: 2.3048, Validation Loss: 2.3050, Validation Accuracy: 9.58%
# Epoch 6, Train Loss: 2.3048, Validation Loss: 2.3050, Validation Accuracy: 9.58%
# Epoch 7, Train Loss: 2.3048, Validation Loss: 2.3050, Validation Accuracy: 9.58%
# Epoch 8, Train Loss: 2.3048, Validation Loss: 2.3050, Validation Accuracy: 9.58%
# Epoch 9, Train Loss: 2.3048, Validation Loss: 2.3050, Validation Accuracy: 9.58%
# Epoch 10, Train Loss: 2.3048, Validation Loss: 2.3050, Validation Accuracy: 9.58%
# Finished Training
# Training Net with Dropout using Adam
# Epoch 1, Train Loss: 2.3055, Validation Loss: 2.3042, Validation Accuracy: 10.30%
# Epoch 2, Train Loss: 2.3054, Validation Loss: 2.3042, Validation Accuracy: 10.30%
# Epoch 3, Train Loss: 2.3052, Validation Loss: 2.3042, Validation Accuracy: 10.30%
# Epoch 4, Train Loss: 2.3052, Validation Loss: 2.3042, Validation Accuracy: 10.30%
# Epoch 5, Train Loss: 2.3055, Validation Loss: 2.3042, Validation Accuracy: 10.30%
# Epoch 6, Train Loss: 2.3053, Validation Loss: 2.3042, Validation Accuracy: 10.30%
# Epoch 7, Train Loss: 2.3055, Validation Loss: 2.3042, Validation Accuracy: 10.30%
# Epoch 8, Train Loss: 2.3054, Validation Loss: 2.3042, Validation Accuracy: 10.30%
# Epoch 9, Train Loss: 2.3054, Validation Loss: 2.3042, Validation Accuracy: 10.30%
# Epoch 10, Train Loss: 2.3053, Validation Loss: 2.3042, Validation Accuracy: 10.30%
# Finished Training

# %%
def evaluate_model(model, testloader):
    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    accuracy = 100 * correct / total
    print(f'Accuracy: {accuracy}%')
    return accuracy

# %%
accuracy_net_without_dropout_sgd = evaluate_model(net_without_dropout, testloader)
accuracy_net_with_dropout_sgd = evaluate_model(net_with_dropout, testloader)
# Out:
# Accuracy: 9.86%
# Accuracy: 9.42%

# %% [markdown]
# ### lets try with batch normalization

# %%
class NetWithBatchNorm(nn.Module):
    def __init__(self):
        super(NetWithBatchNorm, self).__init__()
        self.conv1 = nn.Conv2d(3, 10, 3)
        self.bn1 = nn.BatchNorm2d(10)  # BatchNorm for first conv layer
        self.conv2 = nn.Conv2d(10, 16, 3)
        self.bn2 = nn.BatchNorm2d(16)  # BatchNorm for second conv layer
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(16 * 6 * 6, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.bn1(self.conv1(x))))
        x = self.pool(F.relu(self.bn2(self.conv2(x))))
        x = x.view(-1, 16 * 6 * 6)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

net_batch=NetWithBatchNorm()

# %%
optimizer_adam_with_batchnorm = torch.optim.Adam(net_batch.parameters(), lr=0.001)
print("Training Net with Dropout using SGD")
train_model(net_batch, optimizer_adam_with_batchnorm,num_epochs, trainloader, valloader)
# Out:
# Training Net with Dropout using SGD
# Epoch 1, Train Loss: 0.8725, Validation Loss: 1.0507, Validation Accuracy: 65.86%
# Epoch 2, Train Loss: 0.8539, Validation Loss: 1.0301, Validation Accuracy: 65.70%
# Epoch 3, Train Loss: 0.8341, Validation Loss: 1.0426, Validation Accuracy: 65.82%
# Epoch 4, Train Loss: 0.8144, Validation Loss: 1.0572, Validation Accuracy: 65.61%
# Epoch 5, Train Loss: 0.8027, Validation Loss: 1.0792, Validation Accuracy: 65.84%
# Epoch 6, Train Loss: 0.7803, Validation Loss: 1.0913, Validation Accuracy: 65.41%
# Epoch 7, Train Loss: 0.7723, Validation Loss: 1.1778, Validation Accuracy: 63.46%
# Epoch 8, Train Loss: 0.7605, Validation Loss: 1.0375, Validation Accuracy: 65.67%
# Epoch 9, Train Loss: 0.7438, Validation Loss: 1.0401, Validation Accuracy: 65.85%
# Epoch 10, Train Loss: 0.7294, Validation Loss: 1.1173, Validation Accuracy: 65.35%
# Finished Training

# %%
accuracy_net_with_batch = evaluate_model(net_batch, testloader)
# Out:
# Accuracy: 64.74%
